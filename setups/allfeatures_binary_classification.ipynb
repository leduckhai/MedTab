# %%
# !pip install catboost
# !pip install lightgbm
# Out:
# Collecting catboost
#   Downloading catboost-1.2.5-cp310-cp310-manylinux2014_x86_64.whl (98.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.3.0)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.5
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.11.4)

# %%
import pandas as pd
from dateutil import parser
from collections import defaultdict
from copy import deepcopy
import random
import statistics
import math
import numpy as np
import ast
import statistics
import matplotlib.pyplot as plt

from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, roc_curve, auc, precision_recall_curve

from sklearn.ensemble import GradientBoostingClassifier

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

from catboost import CatBoostClassifier

import lightgbm as lgb

from sklearn.preprocessing import LabelEncoder

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/LDF
# Out:
# /content/drive/.shortcut-targets-by-id/10cLNvGYZ8jCz5UzVVMmUw1kONRPJ_red/LDF

# %% [markdown]
# # Help functions

# %% [markdown]
# ## Data imputation

# %%
def data_imputation(X_train, X_test, imputation_method='mean'):
  # This function imputes the data based on the train set
  # and apply the imputed values to the test set

  if imputation_method == 'mean':

    # Calculate mean per column
    n = len(X_train[0])
    memo = [np.asfarray([0 for i in range(n)]), np.asfarray([0.0 for i in range(n)])] # [Count, Sum]

    for i in range(len(X_train)):
      for j in range(len(X_train[i])):
        if np.isnan(X_train[i][j]) != True:
          memo[0][j] += 1
          memo[1][j] += X_train[i][j]

    for j in range(n):
      memo[1][j] = memo[1][j]/memo[0][j] # ==> [Count, Mean]

    # Data imputation
    for i in range(len(X_train)):
      for j in range(len(X_train[i])):
        if np.isnan(X_train[i][j]) == True:
          X_train[i][j] = memo[1][j]

    for i in range(len(X_test)):
      for j in range(len(X_test[i])):
        if np.isnan(X_test[i][j]) == True:
          X_test[i][j] = memo[1][j]

  return X_train, X_test

# %% [markdown]
# ## In-the-loop normalization

# %%
def data_normalization(X_train, X_test):
  # This function normalizes the data based on the train set
  # and apply the normalized values to the test set

  # Convert to float to get more precise results (yet empirically proved)
  X_train = np.asfarray(X_train)
  X_test = np.asfarray(X_test)

  # Memoization: [Minimums, Maximums]
  memo = deepcopy([X_train[0], X_train[0]])
  for row in X_train:
    for i in range(len(row)):
      if row[i] < memo[0][i]:
        memo[0][i] = row[i]
      if row[i] > memo[1][i]:
        memo[1][i] = row[i]

  # Normalization on train set
  for r in range(len(X_train)):
    for c in range(len(X_train[0])):
      if memo[1][c]-memo[0][c] == 0:
        X_train[r][c] = (X_train[r][c] - memo[0][c])/(1e-20)
      else:
        X_train[r][c] = (X_train[r][c] - memo[0][c])/(memo[1][c]-memo[0][c])

  # Normalization on test set
  for r in range(len(X_test)):
    for c in range(len(X_test[0])):
      if memo[1][c]-memo[0][c] == 0:
        X_test[r][c] = (X_test[r][c] - memo[0][c])/(1e-20)
      else:
        X_test[r][c] = (X_test[r][c] - memo[0][c])/(memo[1][c]-memo[0][c])
      # Rescale
      if X_test[r][c] > 1.0:
        X_test[r][c] = 1.0
      elif X_test[r][c] < 0.0:
        X_test[r][c] = 0.0

  return X_train, X_test

# %% [markdown]
# ## Leave one person out

# %%
def leave_one_person_out(patient_ids):
  loo = dict()
  for patient_id in set(patient_ids):
    loo[patient_id] = None

  for patient_id in loo:
    train_indices, test_indices = [], []

    for i in range(len(patient_ids)):
      if patient_ids[i] == patient_id:
        test_indices.append(i)
      else:
        train_indices.append(i)

    loo[patient_id] = [train_indices, test_indices]

  return loo

# %% [markdown]
# ## K-fold

# %%
def k_fold(patient_ids, number_of_folds = 5):
  patient_id_dict = dict()
  for patient_id in set(patient_ids):
    patient_id_dict[patient_id] = []

  for i in range(len(patient_ids)):
    patient_id = patient_ids[i]
    patient_id_dict[patient_id].append(i)

  kfold_dict = dict()
  i, k = 0, len(patient_id_dict.keys())//number_of_folds
  queue = list(patient_id_dict.keys())

  while queue:
    random.shuffle(queue)
    patient_id_test = [j for j in queue[0:k] ]
    patient_id_train = [j for j in set(patient_id_dict.keys())-set(patient_id_test) ]

    train_indices, test_indices = [], []
    for patient_id in patient_id_train:
      train_indices += patient_id_dict[patient_id]
    for patient_id in patient_id_test:
      test_indices += patient_id_dict[patient_id]
    kfold_dict[i] = [train_indices, test_indices]

    queue = queue[k:]
    i += 1

  return kfold_dict

# %% [markdown]
# ## AUC plot

# %%
def AUC_plot(y, preds):
  figure, axis = plt.subplots(1, 2)

  # ROC AUC
  fpr, tpr, thresholds = roc_curve(y, preds, #pos_label=1
                                   )
  roc_auc = round(auc(fpr, tpr), 4)
  print('ROC AUC: ', roc_auc)
  #print('FPR: ', fpr, 'TPR: ', tpr) # For debugging
  axis[0].plot(fpr, tpr)
  axis[0].set_title('ROC AUC')
  axis[0].set_xlabel('FPR')
  axis[0].set_ylabel('TPR')

  # PR AUC
  precision, recall, thresholds = precision_recall_curve(y, preds, pos_label=1)
  pr_auc = round(auc(recall,precision), 4)
  print('PR AUC: ', pr_auc)
  #print('Recall: ', recall, 'Precision: ', precision) # For debugging
  axis[1].plot(recall, precision)
  axis[1].set_title('ROC PR')
  axis[1].set_xlabel('Recall')
  axis[1].yaxis.set_label_position("right")
  axis[1].set_ylabel('Precision')

  plt.show()

# %% [markdown]
# ## One-hot encoding

# %%
def onehot_encoding(df):
  # Encode categorical variables and store the mapping
  label_encoder = LabelEncoder()
  encoded_values = {}

  for column in df.columns:
    if df[column].dtype == 'O' and column != '1. Volunteer full name':
      df[column] = label_encoder.fit_transform(df[column])
      encoded_values[column] = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

      print(f'Feature: {column} \n', encoded_values[f'{column}'])

  return encoded_values, df

# %% [markdown]
# ## MLP Binary

# %%
# Define the MLP architecture for binary classification
class MLPBinary(nn.Module):
  def __init__(self, input_size, hidden_size, dropout_prob):
    super(MLPBinary, self).__init__()
    self.layer_norm = nn.LayerNorm(input_size)
    self.fc1 = nn.Linear(input_size, hidden_size)
    self.relu = nn.ReLU()
    self.dropout = nn.Dropout(dropout_prob)
    self.fc2 = nn.Linear(hidden_size, hidden_size)
    self.fc3 = nn.Linear(hidden_size, 1)
    self.sigmoid = nn.Sigmoid()

  def forward(self, x):
    out = self.layer_norm(x)
    out = self.fc1(out)
    out = self.relu(out)
    out = self.dropout(out)
    out = self.fc2(out)
    out = self.relu(out)
    out = self.dropout(out)
    out = self.fc3(out)
    out = self.sigmoid(out)
    return out


def MLP_training(X_train, X_test, y_train, y_test):
  # Data imputation
  X_train, X_test = data_imputation(X_train, X_test,
                                    imputation_method='mean')

  # Data normalization
  X_train, X_test = data_normalization(X_train, X_test)

  # Convert NumPy arrays to PyTorch tensors
  y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
  y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

  # Convert data to PyTorch tensors
  X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
  X_test_tensor = torch.tensor(X_test, dtype=torch.float32)

  # Create DataLoader
  train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

  # Initialize model, loss function, and optimizer
  model = MLPBinary(input_size, hidden_size, dropout_prob)
  criterion = nn.BCELoss()
  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  # Define variables to track the best model and its accuracy
  best_accuracy = 0
  best_model = None

  # Training the model
  for epoch in range(num_epochs):
    # Train
    model.train()
    for i, (inputs, labels) in enumerate(train_loader):
      optimizer.zero_grad()
      outputs = model(inputs)
      loss = criterion(outputs, labels.unsqueeze(1))
      loss.backward()
      optimizer.step()

      # Evaluate on train set
      train_outputs = model(X_train_tensor)
      train_predicted = (train_outputs > 0.5).squeeze().int()
      train_accuracy = (train_predicted == y_train_tensor.int()).sum().item() / len(y_train_tensor)

    # Evaluate on test set
    with torch.no_grad():
      model.eval()
      test_outputs = model(X_test_tensor)
      test_predicted = (test_outputs > 0.5).squeeze().int()
      test_accuracy = (test_predicted == y_test_tensor.int()).sum().item() / len(y_test_tensor)

    # Print accuracy for each epoch
    print('Epoch [{}/{}], Train Accuracy: {:.4f}, Test Accuracy: {:.4f}'.format(epoch+1, num_epochs, train_accuracy, test_accuracy))

    # Save the best model
    if test_accuracy > best_accuracy:
      best_accuracy = test_accuracy
      best_model = model.state_dict()

  # Save the best model
  torch.save(best_model, 'best_model.pth')


def MLP_inference(X_test):
  X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
  model = MLPBinary(input_size, hidden_size, dropout_prob)
  model.load_state_dict(torch.load('best_model.pth'))
  model.eval()

  with torch.no_grad():
    y_test_predicted = model(X_test_tensor).squeeze()
    y_test_predicted = y_test_predicted.numpy()

  return y_test_predicted

# %% [markdown]
# # All features - Binary classification

# %%
df_rawdata = pd.read_excel('Data/20-05-2024_TextNorm.xlsx')
print(df_rawdata.dtypes)
df_rawdata
# Out:
# Type of data                                 object
# Patient_ID                                   object
# Kv100                                       float64
# M                                           float64
# δ                                           float64
# T                                           float64
# A365                                        float64
# A460                                        float64
# Anadn                                       float64
# POM                                         float64
# Ae                                          float64
# An                                          float64
# Am                                          float64
# Ar                                          float64
# Ac                                          float64
# F_Ae                                        float64
# F_An                                        float64
# F_Am                                        float64
# F_Ar                                        float64
# F_Ac                                        float64
# Ethnicity                                    object
# Left or Right                                object
# Sleep                                        object
# Gender                                       object
# Race                                         object
# Type of skins                                 int64
# Age                                           int64
# Weight                                      float64
# Height                                        int64
# BMI_index                                   float64
# Smoking                                      object
# Number of cigarettes per week if smoked:    float64
# Disease                                      object
# Blood Pressure                               object
# Level of BP                                   int64
# Heart Rate                                  float64
# DASS_21                                      object
# Stress                                        int64
# Anxiety                                       int64
# Depression                                    int64
# Hypertension                                  int64
# Non-wellbeing                                 int64
# dtype: object
#      Type of data        Patient_ID  Kv100      M     δ      T   A365  A460  \
# 0        Original  Minh Ngoc Nguyen  12.90  22.50  2.90  32.01  114.0  62.0
# 1        Original  Minh Ngoc Nguyen  22.28  22.55  5.02  32.14  122.0  42.0
# 2          Filter  Minh Ngoc Nguyen  11.10  22.85  2.54  32.04  114.0  62.0
# 3          Filter  Minh Ngoc Nguyen  20.78  23.01  4.78  23.01  122.0  41.0
# 4        Original         Hong Pham  20.76   4.39  0.91  24.44  132.0  93.0
# ...           ...               ...    ...    ...   ...    ...    ...   ...
# 1073     Original     Giang Thi Sot  28.89  16.62  4.80  30.75   78.0  97.0
# 1074     Original   Nguyen Ba Tuyen  27.52  18.78  5.17  36.86   92.0  71.0
# 1075     Original   Nguyen Ba Tuyen  10.34  23.96  2.48  35.89   82.0  31.0
# 1076     Original     Mac Van Thang  26.75  24.51  6.56  35.07   53.0  40.0
# 1077     Original     Mac Van Thang   8.55  27.94  2.39  34.01   46.0  26.0
#
#       Anadn    POM  ...         Disease  Blood Pressure  Level of BP  \
# 0      0.54   5.68  ...        Migraine          Normal            0
# 1      0.34  10.38  ...        Migraine          Normal            0
# 2      0.54   7.54  ...        Migraine          Normal            0
# 3      0.33  11.31  ...        Migraine          Normal            0
# 4      0.70   0.91  ...        Migraine          Normal            0
# ...     ...    ...  ...             ...             ...          ...
# 1073   1.24   3.02  ...  Diabetes, MACE        Elevated            1
# 1074   0.77   3.77  ...  Diabetes, MACE        Elevated            1
# 1075   0.37  13.40  ...  Diabetes, MACE        Elevated            1
# 1076   0.77   7.49  ...            MACE        Elevated            1
# 1077   0.58  10.98  ...            MACE        Elevated            1
#
#       Heart Rate  DASS_21  Stress  Anxiety  Depression  Hypertension  \
# 0           95.0   NORMAL       0        0           0             0
# 1           95.0   NORMAL       0        0           0             0
# 2           95.0   NORMAL       0        0           0             0
# 3           95.0   NORMAL       0        0           0             0
# 4           70.0   NORMAL       0        0           0             0
# ...          ...      ...     ...      ...         ...           ...
# 1073        70.0   NORMAL       0        0           0             1
# 1074        70.0   NORMAL       0        0           0             1
# 1075        70.0   NORMAL       0        0           0             1
# 1076        70.0   NORMAL       0        0           0             1
# 1077        70.0   NORMAL       0        0           0             1
#
#       Non-wellbeing
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 1073              0
# 1074              0
# 1075              0
# 1076              0
# 1077              0
#
# [1078 rows x 42 columns]

# %%
# Convert Multiclass to Binary
for i in range(len(df_rawdata['DASS_21'])):
  if df_rawdata['DASS_21'][i] == 'NORMAL':
    pass
  else:
    df_rawdata['DASS_21'][i] = 'ABNORMAL'

# df_rawdata['DASS_21'].unique() # For debugging

# One-hot encoding
encoded_values, df_rawdata = onehot_encoding(df_rawdata)
# Out:
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# Feature: Type of data
#  {'Filter': 0, 'Fragment 1': 1, 'Fragment 2': 2, 'Fragment 3': 3, 'Original': 4, 'fragment1': 5, 'fragment2': 6}
# Feature: Patient_ID
# Feature: Disease
#  {'Anemia': 0, 'Diabetes': 1, 'Diabetes Hypertension': 2, 'Diabetes, MACE': 3, 'Diabetes, degenerative spine': 4, 'Diabetes, hypertension,diabetic complications (MACE)': 5, 'Heart Failure, OAP, Afb': 6, 'Heart Failure, Pneumonia, STEMI': 7, 'Heart Failure, STEMI': 8, 'Heart Failure, STEMI, HYPERTENSION, Diabetes 2': 9, 'Heart Failure, STEMI,BAV3': 10, 'Heart Failure, cononary D with stent placed': 11, 'Heart Failure,STEMI,HYPERTENSION': 12, 'Hepatitis B': 13, 'Hypertension': 14, 'Hypertension Hepatitis B': 15, 'Hypertension Migraine': 16, 'Hypertension Migraine Hepatitis B': 17, 'MACE': 18, 'Migraine': 19, 'No': 20, 'Post Brian Sugery': 21, 'Post sroke': 22, 'Pregnant': 23, 'Thalassemia': 24}
# Feature: Blood Pressure
#  {'Elevated': 0, 'High blood': 1, 'Hypertensive crisis': 2, 'Normal': 3}
# Feature: DASS_21
#  {'ABNORMAL': 0, 'NORMAL': 1}
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-12-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'

# %%
input = ['Type of data','Kv100', 'M', 'δ', 'T', 'A365', 'A460', 'Anadn', 'POM', 'Ae', 'An', 'Am', 'Ar', 'Ac',
         'F_Ae', 'F_An', 'F_Am', 'F_Ar', 'F_Ac', 'Type of skins', 'Age', 'Weight', 'Height', 'BMI_index',
         'Number of cigarettes per week if smoked:', 'Level of BP', 'Heart Rate']
output = [#'Ethnicity', 'Left or Right', 'Sleep', 'Gender', 'Race',
          #'Smoking',
          #'Disease',
          'DASS_21',
          #'Stress', 'Anxiety', 'Depression', 'Hypertension', 'Non-wellbeing'
          ]

X_rawdata = df_rawdata[input].values
y_dass21 = df_rawdata['DASS_21'].values

patient_ids = list(df_rawdata['Patient_ID'])

# %% [markdown]
# ## Leave-one-patient-out

# %% [markdown]
# ### Gradient Boosting

# %%
# Gradient Boosting
d_preds = {'labels': [], 'preds': []}

loo = leave_one_person_out(patient_ids)

for patient_id in loo:
  # Leave one out
  train_indices = np.array(loo[patient_id][0])
  test_indices = np.array(loo[patient_id][1])

  X_rawdata_train = X_rawdata[train_indices]
  X_rawdata_test = X_rawdata[test_indices]
  y_dass21_train = y_dass21[train_indices]
  y_dass21_test = y_dass21[test_indices]

  # Data imputation
  X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                    imputation_method='mean')

  # Classification
  clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
                                   max_depth=1, random_state=0).fit(X_rawdata_train, y_dass21_train)
  d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
  d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('Gradient Boosting')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Gradient Boosting
# ROC AUC:  0.6556
# PR AUC:  0.8806

# %% [markdown]
# ### Catboost

# %%
# Catboost
d_preds = {'labels': [], 'preds': []}

loo = leave_one_person_out(patient_ids)

for patient_id in loo:
  # Leave one out
  train_indices = np.array(loo[patient_id][0])
  test_indices = np.array(loo[patient_id][1])

  X_rawdata_train = X_rawdata[train_indices]
  X_rawdata_test = X_rawdata[test_indices]
  y_dass21_train = y_dass21[train_indices]
  y_dass21_test = y_dass21[test_indices]

  # Data imputation
  X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                    imputation_method='mean')

  # Classification
  clf = CatBoostClassifier(iterations=2, learning_rate=1, depth=2)
  clf.fit(X_rawdata_train, y_dass21_train, verbose=False)
  d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
  d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('Catboost')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Catboost
# ROC AUC:  0.6001
# PR AUC:  0.8287

# %% [markdown]
# ### LightGBM

# %%
# LightGBM
d_preds = {'labels': [], 'preds': []}

loo = leave_one_person_out(patient_ids)

for patient_id in loo:
  # Leave one out
  train_indices = np.array(loo[patient_id][0])
  test_indices = np.array(loo[patient_id][1])

  X_rawdata_train = X_rawdata[train_indices]
  X_rawdata_test = X_rawdata[test_indices]
  y_dass21_train = y_dass21[train_indices]
  y_dass21_test = y_dass21[test_indices]

  # Data imputation
  X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                    imputation_method='mean')

  # Classification
  train_data = lgb.Dataset(X_rawdata_train, label=y_dass21_train)
  test_data = lgb.Dataset(X_rawdata_test, label=y_dass21_test, reference=train_data)
  params = {
      'objective': 'binary',
      'metric': 'binary_logloss',
      'num_leaves': 31,
      #'learning_rate': 0.05,
      'learning_rate': 0.1,
      'n_estimators': 100,
      'verbose': -1
  }
  bst = lgb.train(params, train_data, valid_sets=[train_data, test_data])
  y_dass21_test_preds = bst.predict(X_rawdata_test, num_iteration=bst.best_iteration)

  d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
  d_preds['preds'] += [ np.array(val) for val in y_dass21_test_preds ]

print('LightGBM')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:172: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# LightGBM
# ROC AUC:  0.6773
# PR AUC:  0.8998

# %% [markdown]
# ### SVM

# %%
# SVM
d_preds = {'labels': [], 'preds': []}

loo = leave_one_person_out(patient_ids)

for patient_id in loo:
  # Leave one out
  train_indices = np.array(loo[patient_id][0])
  test_indices = np.array(loo[patient_id][1])

  X_rawdata_train = X_rawdata[train_indices]
  X_rawdata_test = X_rawdata[test_indices]
  y_dass21_train = y_dass21[train_indices]
  y_dass21_test = y_dass21[test_indices]

  # Data imputation
  X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                    imputation_method='mean')

  # Classification
  clf = make_pipeline(StandardScaler(), SVC(gamma='auto', probability=True))
  clf.fit(X_rawdata_train, y_dass21_train)
  d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
  d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('SVM')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# SVM
# ROC AUC:  0.5316
# PR AUC:  0.8214

# %% [markdown]
# ### Random forest

# %%
# Random forest
d_preds = {'labels': [], 'preds': []}

loo = leave_one_person_out(patient_ids)

for patient_id in loo:
  # Leave one out
  train_indices = np.array(loo[patient_id][0])
  test_indices = np.array(loo[patient_id][1])

  X_rawdata_train = X_rawdata[train_indices]
  X_rawdata_test = X_rawdata[test_indices]
  y_dass21_train = y_dass21[train_indices]
  y_dass21_test = y_dass21[test_indices]

  # Data imputation
  X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                    imputation_method='mean')

  # Classification
  clf = RandomForestClassifier(max_depth=2, random_state=0)
  clf.fit(X_rawdata_train, y_dass21_train)
  d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
  d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('Random forest')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Random forest
# ROC AUC:  0.6209
# PR AUC:  0.863

# %% [markdown]
# ### MLP

# %%
# MLP

# Define hyperparameters
input_size = X_rawdata.shape[1]
hidden_size = 64
num_epochs = 20
batch_size = 32
dropout_prob = 0.05
learning_rate = 0.001

d_preds = {'labels': [], 'preds': []}

loo = leave_one_person_out(patient_ids)

for patient_id in loo:
  # Leave one out
  train_indices = np.array(loo[patient_id][0])
  test_indices = np.array(loo[patient_id][1])

  X_rawdata_train = X_rawdata[train_indices]
  X_rawdata_test = X_rawdata[test_indices]
  y_dass21_train = y_dass21[train_indices]
  y_dass21_test = y_dass21[test_indices]

  # Data imputation
  X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                    imputation_method='mean')

  # Dummy
  flag = None
  if len(set(y_dass21_test)) == 1:
    for i in range(len(y_dass21)):
      if y_dass21[i] == 1 - y_dass21_test[0]:
        X_rawdata_test = np.concatenate((np.reshape(X_rawdata[i], (1,-1)), X_rawdata_test), axis=0)
        y_dass21_test = np.concatenate((np.array([y_dass21[i]]), y_dass21_test), axis=0)
        flag = True
        break

  # Classification
  MLP_training(X_rawdata_train, X_rawdata_test, y_dass21_train, y_dass21_test)
  y_test_predicted = MLP_inference(X_rawdata_test)

  if flag == True:
    y_dass21_test, y_test_predicted = y_dass21_test[1:], y_test_predicted[1:]

  d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
  d_preds['preds'] += [ np.array(val) for val in y_test_predicted ]

print('MLP')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Epoch [1/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [2/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [3/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [4/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [5/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [6/20], Train Accuracy: 0.7972, Test Accuracy: 0.1111
# Epoch [7/20], Train Accuracy: 0.8093, Test Accuracy: 0.1111
# Epoch [8/20], Train Accuracy: 0.8215, Test Accuracy: 0.1111
# Epoch [9/20], Train Accuracy: 0.8449, Test Accuracy: 0.1111
# Epoch [10/20], Train Accuracy: 0.8626, Test Accuracy: 0.1111
# Epoch [11/20], Train Accuracy: 0.8168, Test Accuracy: 0.1111
# Epoch [12/20], Train Accuracy: 0.8720, Test Accuracy: 0.1111
# Epoch [13/20], Train Accuracy: 0.8888, Test Accuracy: 0.1111
# Epoch [14/20], Train Accuracy: 0.8850, Test Accuracy: 0.1111
# Epoch [15/20], Train Accuracy: 0.8897, Test Accuracy: 0.1111
# Epoch [16/20], Train Accuracy: 0.8869, Test Accuracy: 0.1111
# Epoch [17/20], Train Accuracy: 0.8991, Test Accuracy: 0.1111
# Epoch [18/20], Train Accuracy: 0.8935, Test Accuracy: 0.1111
# Epoch [19/20], Train Accuracy: 0.9056, Test Accuracy: 0.1111
# Epoch [20/20], Train Accuracy: 0.9187, Test Accuracy: 0.1111
# Epoch [1/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [2/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [3/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [4/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [5/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [6/20], Train Accuracy: 0.7924, Test Accuracy: 0.8000
# Epoch [7/20], Train Accuracy: 0.7998, Test Accuracy: 0.8000
# Epoch [8/20], Train Accuracy: 0.8026, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.7980, Test Accuracy: 0.8000
# Epoch [10/20], Train Accuracy: 0.8259, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8426, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8333, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8585, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8715, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8687, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8538, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8762, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9088, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8994, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8929, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7992, Test Accuracy: 0.0769
# Epoch [2/20], Train Accuracy: 0.7992, Test Accuracy: 0.0769
# Epoch [3/20], Train Accuracy: 0.7992, Test Accuracy: 0.0769
# Epoch [4/20], Train Accuracy: 0.7992, Test Accuracy: 0.0769
# Epoch [5/20], Train Accuracy: 0.8265, Test Accuracy: 0.0769
# Epoch [6/20], Train Accuracy: 0.8255, Test Accuracy: 0.0769
# Epoch [7/20], Train Accuracy: 0.8133, Test Accuracy: 0.0769
Test Accuracy: 0.3333
# Epoch [19/20], Train Accuracy: 0.9191, Test Accuracy: 0.6667
# Epoch [20/20], Train Accuracy: 0.8987, Test Accuracy: 0.3333
# Epoch [1/20], Train Accuracy: 0.7870, Test Accuracy: 0.9444
# Epoch [2/20], Train Accuracy: 0.7870, Test Accuracy: 0.9444
# Epoch [3/20], Train Accuracy: 0.7870, Test Accuracy: 0.9444
# Epoch [4/20], Train Accuracy: 0.7870, Test Accuracy: 0.9444
# Epoch [5/20], Train Accuracy: 0.7870, Test Accuracy: 0.9444
# Epoch [6/20], Train Accuracy: 0.7889, Test Accuracy: 0.9444
# Epoch [7/20], Train Accuracy: 0.8002, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8040, Test Accuracy: 0.9444
# Epoch [9/20], Train Accuracy: 0.8369, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8445, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8577, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8652, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8841, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8850, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8888, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8888, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9001, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8954, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9095, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9265, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8078, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8152, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8301, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8357, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8552, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8589, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8644, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8867, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8858, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8886, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9034, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9127, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9174, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9257, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9192, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8087, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8124, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8319, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8227, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8505, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8477, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8598, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8765, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.9034, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8877, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9109, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9211, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9127, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9109, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9322, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7939, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7985, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8097, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8338, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8477, Test Accuracy: 0.5000
# Epoch [10/20], Train Accuracy: 0.8468, Test Accuracy: 0.5000
# Epoch [11/20], Train Accuracy: 0.8570, Test Accuracy: 0.5000
# Epoch [12/20], Train Accuracy: 0.8552, Test Accuracy: 0.5000
# Epoch [13/20], Train Accuracy: 0.8839, Test Accuracy: 0.5000
# Epoch [14/20], Train Accuracy: 0.8867, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8663, Test Accuracy: 0.5000
# Epoch [16/20], Train Accuracy: 0.9062, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8997, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9183, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9257, Test Accuracy: 0.5000
# Epoch [20/20], Train Accuracy: 0.9211, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7929, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8041, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8292, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8180, Test Accuracy: 0.5000
# Epoch [10/20], Train Accuracy: 0.8487, Test Accuracy: 0.5000
# Epoch [11/20], Train Accuracy: 0.8570, Test Accuracy: 0.5000
# Epoch [12/20], Train Accuracy: 0.8747, Test Accuracy: 0.5000
# Epoch [13/20], Train Accuracy: 0.8839, Test Accuracy: 0.5000
# Epoch [14/20], Train Accuracy: 0.8960, Test Accuracy: 0.5000
# Epoch [15/20], Train Accuracy: 0.8997, Test Accuracy: 0.5000
# Epoch [16/20], Train Accuracy: 0.9006, Test Accuracy: 0.5000
# Epoch [17/20], Train Accuracy: 0.9090, Test Accuracy: 0.5000
# Epoch [18/20], Train Accuracy: 0.9034, Test Accuracy: 0.5000
# Epoch [19/20], Train Accuracy: 0.9276, Test Accuracy: 0.5000
# Epoch [20/20], Train Accuracy: 0.9239, Test Accuracy: 0.5000
# Epoch [1/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8004, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8004, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8310, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.
Test Accuracy: 0.3333
# Epoch [19/20], Train Accuracy: 0.9154, Test Accuracy: 0.3333
# Epoch [20/20], Train Accuracy: 0.9099, Test Accuracy: 0.3333
# Epoch [1/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [2/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [3/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [4/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [5/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [6/20], Train Accuracy: 0.8047, Test Accuracy: 0.1111
# Epoch [7/20], Train Accuracy: 0.8047, Test Accuracy: 0.1111
# Epoch [8/20], Train Accuracy: 0.8308, Test Accuracy: 0.1111
# Epoch [9/20], Train Accuracy: 0.8355, Test Accuracy: 0.1111
# Epoch [10/20], Train Accuracy: 0.8495, Test Accuracy: 0.1111
# Epoch [11/20], Train Accuracy: 0.8664, Test Accuracy: 0.1111
# Epoch [12/20], Train Accuracy: 0.8757, Test Accuracy: 0.1111
# Epoch [13/20], Train Accuracy: 0.8841, Test Accuracy: 0.1111
# Epoch [14/20], Train Accuracy: 0.8888, Test Accuracy: 0.1111
# Epoch [15/20], Train Accuracy: 0.8925, Test Accuracy: 0.2222
# Epoch [16/20], Train Accuracy: 0.8757, Test Accuracy: 0.1111
# Epoch [17/20], Train Accuracy: 0.9000, Test Accuracy: 0.1111
# Epoch [18/20], Train Accuracy: 0.9084, Test Accuracy: 0.3333
# Epoch [19/20], Train Accuracy: 0.9065, Test Accuracy: 0.3333
# Epoch [20/20], Train Accuracy: 0.9112, Test Accuracy: 0.1111
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8004, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8124, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8236, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8134, Test Accuracy: 0.5000
# Epoch [10/20], Train Accuracy: 0.8273, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8403, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8264, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8487, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8700, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8672, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8802, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8914, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8988, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9044, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9099, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [2/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [3/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [4/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [5/20], Train Accuracy: 0.7931, Test Accuracy: 0.9091
# Epoch [6/20], Train Accuracy: 0.7987, Test Accuracy: 0.9091
# Epoch [7/20], Train Accuracy: 0.8212, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8249, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8399, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8511, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8633, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8783, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8699, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8848, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8848, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9101, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9073, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9139, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9036, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9345, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.7937, Test Accuracy: 0.6667
# Epoch [7/20], Train Accuracy: 0.7937, Test Accuracy: 0.6667
# Epoch [8/20], Train Accuracy: 0.8067, Test Accuracy: 0.6667
# Epoch [9/20], Train Accuracy: 0.8309, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8271, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8532, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8504, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8690, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8727, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8913, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8885, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9108, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9061, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9173, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9136, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7957, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8004, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8152, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8254, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8384, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8514, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8579, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8793, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8774, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8719, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8997, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9053, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9062, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9118, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9099, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9164, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7888, Test Accuracy: 0.8889
# Epoch [2/20], Train Accuracy: 0.7888, Test Accuracy: 0.8889
# Epoch [3/20], Train Accuracy: 0.7888, Test Accuracy: 0.8889
# Epoch [4/20], Train Accuracy: 0.7888, Test Accuracy: 0.8889
# Epoch [5/20], Train Accuracy: 0.7935, Test Accuracy: 0.8889
# Epoch [6/20], Train Accuracy: 0.8028, Test Accuracy: 0.8889
# Epoch [7/20], Train Accuracy: 0.8037, Test Accuracy: 0.8889
# Epoch [8/20], Train Accuracy: 0.8262, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.
20], Train Accuracy: 0.7872, Test Accuracy: 0.9412
# Epoch [4/20], Train Accuracy: 0.7872, Test Accuracy: 0.9412
# Epoch [5/20], Train Accuracy: 0.8032, Test Accuracy: 0.9412
# Epoch [6/20], Train Accuracy: 0.7966, Test Accuracy: 0.9412
# Epoch [7/20], Train Accuracy: 0.8023, Test Accuracy: 0.9412
# Epoch [8/20], Train Accuracy: 0.8089, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8220, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8202, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8286, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8324, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8588, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8380, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8616, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8804, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8936, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9068, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8964, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9068, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [2/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [3/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [4/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [5/20], Train Accuracy: 0.8045, Test Accuracy: 1.0000
# Epoch [6/20], Train Accuracy: 0.7961, Test Accuracy: 0.8000
# Epoch [7/20], Train Accuracy: 0.8101, Test Accuracy: 0.8000
# Epoch [8/20], Train Accuracy: 0.8212, Test Accuracy: 0.8000
# Epoch [9/20], Train Accuracy: 0.8520, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8482, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8696, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8790, Test Accuracy: 0.8000
# Epoch [13/20], Train Accuracy: 0.8762, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8892, Test Accuracy: 0.8000
# Epoch [15/20], Train Accuracy: 0.8901, Test Accuracy: 0.8000
# Epoch [16/20], Train Accuracy: 0.9004, Test Accuracy: 0.8000
# Epoch [17/20], Train Accuracy: 0.9171, Test Accuracy: 0.8000
# Epoch [18/20], Train Accuracy: 0.8939, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9162, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9171, Test Accuracy: 0.8000
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.8113, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8216, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8243, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8309, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8550, Test Accuracy: 0.6667
# Epoch [11/20], Train Accuracy: 0.8606, Test Accuracy: 0.6667
# Epoch [12/20], Train Accuracy: 0.8810, Test Accuracy: 0.6667
# Epoch [13/20], Train Accuracy: 0.8922, Test Accuracy: 0.6667
# Epoch [14/20], Train Accuracy: 0.9015, Test Accuracy: 0.6667
# Epoch [15/20], Train Accuracy: 0.9033, Test Accuracy: 0.6667
# Epoch [16/20], Train Accuracy: 0.9099, Test Accuracy: 0.3333
# Epoch [17/20], Train Accuracy: 0.9247, Test Accuracy: 0.3333
# Epoch [18/20], Train Accuracy: 0.9294, Test Accuracy: 0.3333
# Epoch [19/20], Train Accuracy: 0.9294, Test Accuracy: 0.6667
# Epoch [20/20], Train Accuracy: 0.9349, Test Accuracy: 0.3333
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.8151, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.8234, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8290, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8439, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8550, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8550, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8699, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8810, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8857, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8727, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.9210, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9136, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9191, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9238, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9061, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9387, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.7918, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.7983, Test Accuracy: 0.6667
# Epoch [7/20], Train Accuracy: 0.8216, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8336, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8457, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8448, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8708, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8727, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8690, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8838, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.9006, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9006, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9024, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9173, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9126, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9154, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.7909, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.8030, Test Accuracy: 0.6667
# Epoch [7/20], Train Accuracy: 0.8216, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8411, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8169, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8364, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8634, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8792, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8727, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8987, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8857, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8875, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9154, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9238, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9164, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9322, Test Accuracy: 0.6667
# Epoch [1/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [2/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [3/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [4/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [5/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [6/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [7/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [8/20], Train Accuracy: 0.7961, Test Accuracy: 0.8000
# Epoch [9/20], Train Accuracy: 0.8119, Test Accuracy: 0.8000
# Epoch [10/20], Train Accuracy: 0.8436, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8669, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8808, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8752, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8873, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8790, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9013, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9088, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8994, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9032, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9218, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [2/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [3/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [4/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [5/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [6/20], Train Accuracy: 0.7914, Test Accuracy: 0.8000
# Epoch [7/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [8/20], Train Accuracy: 0.8175, Test Accuracy: 0.8000
# Epoch [9/20], Train Accuracy: 0.8203, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8184, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8492, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8547, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8520, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8752, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8631, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8901, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8771, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8994, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9143, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9050, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [2/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [3/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [4/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch
# Epoch [15/20], Train Accuracy: 0.9056, Test Accuracy: 0.3333
# Epoch [16/20], Train Accuracy: 0.9196, Test Accuracy: 0.4444
# Epoch [17/20], Train Accuracy: 0.9121, Test Accuracy: 0.1111
# Epoch [18/20], Train Accuracy: 0.9234, Test Accuracy: 0.3333
# Epoch [19/20], Train Accuracy: 0.9336, Test Accuracy: 0.2222
# Epoch [20/20], Train Accuracy: 0.9458, Test Accuracy: 0.3333
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [7/20], Train Accuracy: 0.7937, Test Accuracy: 0.6667
# Epoch [8/20], Train Accuracy: 0.8123, Test Accuracy: 0.6667
# Epoch [9/20], Train Accuracy: 0.8225, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8392, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8625, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8522, Test Accuracy: 1.0000
# ...
# Epoch [18/20], Train Accuracy: 0.9118, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9220, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9016, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.8013, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8087, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8115, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8152, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8514, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8682, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8533, Test Accuracy: 0.5000
# Epoch [12/20], Train Accuracy: 0.8617, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8756, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8858, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8988, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9025, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9081, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9118, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9155, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9341, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.7929, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8004, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8134, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8357, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8607, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8626, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8747, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8886, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8979, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9044, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9136, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9146, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9109, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9062, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7929, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8032, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8180, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8199, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8440, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8514, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8737, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8747, Test Accuracy: 0.5000
# Epoch [14/20], Train Accuracy: 0.8784, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8867, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8969, Test Accuracy: 0.5000
# Epoch [17/20], Train Accuracy: 0.8858, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8969, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9127, Test Accuracy: 0.5000
# Epoch [20/20], Train Accuracy: 0.9229, Test Accuracy: 0.5000
# Epoch [1/20], Train Accuracy: 0.7880, Test Accuracy: 0.9231
# Epoch [2/20], Train Accuracy: 0.7880, Test Accuracy: 0.9231
# Epoch [3/20], Train Accuracy: 0.7880, Test Accuracy: 0.9231
# Epoch [4/20], Train Accuracy: 0.7880, Test Accuracy: 0.9231
# Epoch [5/20], Train Accuracy: 0.7889, Test Accuracy: 0.9231
# Epoch [6/20], Train Accuracy: 0.8030, Test Accuracy: 0.9231
# Epoch [7/20], Train Accuracy: 0.8133, Test Accuracy: 0.9231
# Epoch [8/20], Train Accuracy: 0.8171, Test Accuracy: 0.9231
# Epoch [9/20], Train Accuracy: 0.8265, Test Accuracy: 0.9231
# Epoch [10/20], Train Accuracy: 0.8480, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8499, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8771, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8818, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8912, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.9062, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9184, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8968, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9146, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9231, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9221, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7939, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7948, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8069, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8273, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8607, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8487, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8793, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8802, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.9071, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.9006, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8858, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9146, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9304, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9266, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9304, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9369, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [2/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [3/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [4/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [5/20], Train Accuracy: 0.7893, Test Accuracy: 0.9091
# Epoch [6/20], Train Accuracy: 0.7978, Test Accuracy: 0.9091
# Epoch [7/20], Train Accuracy: 0.8024, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8127, Test Accuracy: 0.9091
# Epoch [9/20], Train Accuracy: 0.8586, Test Accuracy: 0.3636
# Epoch [10/20], Train Accuracy: 0.8521, Test Accuracy: 0.7273
# Epoch [11/20], Train Accuracy: 0.8699, Test Accuracy: 0.5455
# Epoch [12/20], Train Accuracy: 0.8689, Test Accuracy: 0.6364
# Epoch [13/20], Train Accuracy: 0.8970, Test Accuracy: 0.1818
# Epoch [14/20], Train Accuracy: 0.8886, Test Accuracy: 0.6364
# Epoch [15/20], Train Accuracy: 0.9036, Test Accuracy: 0.1818
# Epoch [16/20], Train Accuracy: 0.8989, Test Accuracy: 0.7273
# Epoch [17/20], Train Accuracy: 0.9195, Test Accuracy: 0.1818
# Epoch [18/20], Train Accuracy: 0.9260, Test Accuracy: 0.2727
# Epoch [19/20], Train Accuracy: 0.9232, Test Accuracy: 0.1818
# Epoch [20/20], Train Accuracy: 0.8848, Test Accuracy: 0.8182
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7929, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8032, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8189, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8245, Test Accuracy: 0.5000
# Epoch [10/20], Train Accuracy: 0.8366, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8487, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8617, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8663, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8830, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8821, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8644, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8969, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8858, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9090, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9062, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.7920, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8004, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8115, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8477, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8394, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8477, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8477, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8747, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8756, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8988, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8914, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8942, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9006, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9146, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.7994, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8115, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8199, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8208, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8440, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8524, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8644, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8654, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8942, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8932, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8988, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8988, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9192, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9146, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.7976, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8106, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8124, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8292, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8672, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8542, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8524, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8904, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9006, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9006, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9044, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9155, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9192, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.7976, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8162, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8217, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8598, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8514, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8579, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8774, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8654, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8895, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8932, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9109, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8969, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9127, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9118, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7976, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8097, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8199, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8310, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8384, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8672, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8552, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8756, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8793, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.9044, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9016, Test Accuracy: 0.5000
# Epoch [17/20], Train Accuracy: 0.9034, Test Accuracy: 0.5000
# Epoch [18/20], Train Accuracy: 0.9136, Test Accuracy: 0.5000
# Epoch [19/20], Train Accuracy: 0.9053, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9387, Test Accuracy: 0.5000
# Epoch [1/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7985, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8032, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8412, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8384, Test Accuracy: 0.5000
# Epoch [10/20], Train Accuracy: 0.8635, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8672, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8765, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8691, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8867, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.9071, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8886, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9099, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9201, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9248, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9313, Test Accuracy: 1.0000
# MLP
# ROC AUC:  0.5313
# PR AUC:  0.8425

# %% [markdown]
# ## K-fold

# %% [markdown]
# ### Gradient Boosting

# %%
# Gradient Boosting
d_preds = {'labels': [], 'preds': []}

for seed in range(10):
  kfold = k_fold(patient_ids, number_of_folds=5)
  for k in kfold:
    # K-fold
    train_indices = np.array(kfold[k][0])
    test_indices = np.array(kfold[k][1])

    X_rawdata_train = X_rawdata[train_indices]
    X_rawdata_test = X_rawdata[test_indices]
    y_dass21_train = y_dass21[train_indices]
    y_dass21_test = y_dass21[test_indices]

    # Data imputation
    X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                      imputation_method='mean')

    # Classification
    clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
                                    max_depth=1, random_state=0).fit(X_rawdata_train, y_dass21_train)
    d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
    d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('Gradient Boosting')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Gradient Boosting
# ROC AUC:  0.6292
# PR AUC:  0.8529

# %% [markdown]
# ### Catboost

# %%
# Catboost
d_preds = {'labels': [], 'preds': []}

for seed in range(10):
  kfold = k_fold(patient_ids, number_of_folds=5)
  for k in kfold:
    # K-fold
    train_indices = np.array(kfold[k][0])
    test_indices = np.array(kfold[k][1])

    X_rawdata_train = X_rawdata[train_indices]
    X_rawdata_test = X_rawdata[test_indices]
    y_dass21_train = y_dass21[train_indices]
    y_dass21_test = y_dass21[test_indices]

    # Data imputation
    X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                      imputation_method='mean')

    # Classification
    clf = CatBoostClassifier(iterations=2, learning_rate=1, depth=2)
    clf.fit(X_rawdata_train, y_dass21_train, verbose=False)
    d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
    d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('Catboost')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Catboost
# ROC AUC:  0.5511
# PR AUC:  0.8232

# %% [markdown]
# ### LightGBM

# %%
# LightGBM
d_preds = {'labels': [], 'preds': []}

for seed in range(10):
  kfold = k_fold(patient_ids, number_of_folds=5)
  for k in kfold:
    # K-fold
    train_indices = np.array(kfold[k][0])
    test_indices = np.array(kfold[k][1])

    X_rawdata_train = X_rawdata[train_indices]
    X_rawdata_test = X_rawdata[test_indices]
    y_dass21_train = y_dass21[train_indices]
    y_dass21_test = y_dass21[test_indices]

    # Data imputation
    X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                      imputation_method='mean')

    # Classification
  train_data = lgb.Dataset(X_rawdata_train, label=y_dass21_train)
  test_data = lgb.Dataset(X_rawdata_test, label=y_dass21_test, reference=train_data)
  params = {
      'objective': 'binary',
      'metric': 'binary_logloss',
      'num_leaves': 31,
      #'learning_rate': 0.05,
      'learning_rate': 0.1,
      'n_estimators': 100,
      'verbose': -1
  }
  bst = lgb.train(params, train_data, valid_sets=[train_data, test_data])
  y_dass21_test_preds = bst.predict(X_rawdata_test, num_iteration=bst.best_iteration)

  d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
  d_preds['preds'] += [ np.array(val) for val in y_dass21_test_preds ]

print('LightGBM')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:172: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# LightGBM
# ROC AUC:  0.6888
# PR AUC:  0.8714

# %% [markdown]
# ### SVM

# %%
# SVM
d_preds = {'labels': [], 'preds': []}

for seed in range(10):
  kfold = k_fold(patient_ids, number_of_folds=5)
  for k in kfold:
    # K-fold
    train_indices = np.array(kfold[k][0])
    test_indices = np.array(kfold[k][1])

    X_rawdata_train = X_rawdata[train_indices]
    X_rawdata_test = X_rawdata[test_indices]
    y_dass21_train = y_dass21[train_indices]
    y_dass21_test = y_dass21[test_indices]

    # Data imputation
    X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                      imputation_method='mean')

    # Classification
    clf = make_pipeline(StandardScaler(), SVC(gamma='auto', probability=True))
    clf.fit(X_rawdata_train, y_dass21_train)
    d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
    d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('SVM')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# SVM
# ROC AUC:  0.5571
# PR AUC:  0.8184

# %% [markdown]
# ### Random forest

# %%
# Random forest
d_preds = {'labels': [], 'preds': []}

for seed in range(10):
  kfold = k_fold(patient_ids, number_of_folds=5)
  for k in kfold:
    # K-fold
    train_indices = np.array(kfold[k][0])
    test_indices = np.array(kfold[k][1])

    X_rawdata_train = X_rawdata[train_indices]
    X_rawdata_test = X_rawdata[test_indices]
    y_dass21_train = y_dass21[train_indices]
    y_dass21_test = y_dass21[test_indices]

    # Data imputation
    X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                      imputation_method='mean')

    # Classification
    clf = RandomForestClassifier(max_depth=2, random_state=0)
    clf.fit(X_rawdata_train, y_dass21_train)
    d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
    d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('Random forest')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Random forest
# ROC AUC:  0.6257
# PR AUC:  0.8597

# %% [markdown]
# ### MLP

# %%
# MLP

# Define hyperparameters
input_size = X_rawdata.shape[1]
hidden_size = 64
num_epochs = 20
batch_size = 32
dropout_prob = 0.05
learning_rate = 0.001

d_preds = {'labels': [], 'preds': []}

for seed in range(10):
  kfold = k_fold(patient_ids, number_of_folds=5)
  for k in kfold:
    # K-fold
    train_indices = np.array(kfold[k][0])
    test_indices = np.array(kfold[k][1])

    X_rawdata_train = X_rawdata[train_indices]
    X_rawdata_test = X_rawdata[test_indices]
    y_dass21_train = y_dass21[train_indices]
    y_dass21_test = y_dass21[test_indices]

    # Data imputation
    X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                      imputation_method='mean')

    # Dummy
    flag = None
    if len(set(y_dass21_test)) == 1:
      for i in range(len(y_dass21)):
        if y_dass21[i] == 1 - y_dass21_test[0]:
          X_rawdata_test = np.concatenate((np.reshape(X_rawdata[i], (1,-1)), X_rawdata_test), axis=0)
          y_dass21_test = np.concatenate((np.array([y_dass21[i]]), y_dass21_test), axis=0)
          flag = True
          break

    # Classification
    MLP_training(X_rawdata_train, X_rawdata_test, y_dass21_train, y_dass21_test)
    y_test_predicted = MLP_inference(X_rawdata_test)

    if flag == True:
      y_dass21_test, y_test_predicted = y_dass21_test[1:], y_test_predicted[1:]

    d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
    d_preds['preds'] += [ np.array(val) for val in y_test_predicted ]

print('MLP')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Epoch [1/20], Train Accuracy: 0.7984, Test Accuracy: 0.7561
# Epoch [2/20], Train Accuracy: 0.7984, Test Accuracy: 0.7561
# Epoch [3/20], Train Accuracy: 0.7984, Test Accuracy: 0.7561
# Epoch [4/20], Train Accuracy: 0.7984, Test Accuracy: 0.7561
# Epoch [5/20], Train Accuracy: 0.7984, Test Accuracy: 0.7561
# Epoch [6/20], Train Accuracy: 0.7984, Test Accuracy: 0.7561
# Epoch [7/20], Train Accuracy: 0.7984, Test Accuracy: 0.7561
# Epoch
# Epoch [17/20], Train Accuracy: 0.8904, Test Accuracy: 0.7782
# Epoch [18/20], Train Accuracy: 0.9054, Test Accuracy: 0.7709
# Epoch [19/20], Train Accuracy: 0.9253, Test Accuracy: 0.7745
# Epoch [20/20], Train Accuracy: 0.9215, Test Accuracy: 0.7709
# Epoch [1/20], Train Accuracy: 0.8212, Test Accuracy: 0.6393
# Epoch [2/20], Train Accuracy: 0.8212, Test Accuracy: 0.6393
# Epoch [3/20], Train Accuracy: 0.8212, Test Accuracy: 0.6393
# Epoch [4/20], Train Accuracy: 0.8212, Test Accuracy: 0.6393
# Epoch [5/20], Train Accuracy: 0.8212, Test Accuracy: 0.6393
# Epoch [6/20], Train Accuracy: 0.8212, Test Accuracy: 0.6393
# Epoch [7/20], Train Accuracy: 0.8313, Test Accuracy: 0.6393
# Epoch [8/20], Train Accuracy: 0.8291, Test Accuracy: 0.6393
# Epoch [9/20], Train Accuracy: 0.8346, Test Accuracy: 0.6393
# Epoch [10/20], Train Accuracy: 0.8626, Test Accuracy: 0.6448
# Epoch [11/20], Train Accuracy: 0.8615, Test Accuracy: 0.6393
# Epoch [12/20], Train Accuracy: 0.8827, Test Accuracy: 0.6503
# Epoch [13/20], Train Accuracy: 0.8804, Test Accuracy: 0.6448
# Epoch [14/20], Train Accuracy: 0.8816, Test Accuracy: 0.6448
# Epoch [15/20], Train Accuracy: 0.8961, Test Accuracy: 0.6339
# Epoch [16/20], Train Accuracy: 0.8950, Test Accuracy: 0.6230
# Epoch [17/20], Train Accuracy: 0.9050, Test Accuracy: 0.6284
# Epoch [18/20], Train Accuracy: 0.8927, Test Accuracy: 0.6284
# Epoch [19/20], Train Accuracy: 0.9251, Test Accuracy: 0.6120
# Epoch [20/20], Train Accuracy: 0.9151, Test Accuracy: 0.6284
# Epoch [1/20], Train Accuracy: 0.7903, Test Accuracy: 0.7906
# Epoch [2/20], Train Accuracy: 0.7903, Test Accuracy: 0.7906
# Epoch [3/20], Train Accuracy: 0.7903, Test Accuracy: 0.7906
# Epoch [4/20], Train Accuracy: 0.7927, Test Accuracy: 0.7906
# Epoch [5/20], Train Accuracy: 0.8009, Test Accuracy: 0.7906
# Epoch [6/20], Train Accuracy: 0.8069, Test Accuracy: 0.7906
# Epoch [7/20], Train Accuracy: 0.8164, Test Accuracy: 0.7863
# Epoch [8/20], Train Accuracy: 0.8211, Test Accuracy: 0.7650
# Epoch [9/20], Train Accuracy: 0.8270, Test Accuracy: 0.7265
# Epoch [10/20], Train Accuracy: 0.8294, Test Accuracy: 0.7692
# Epoch [11/20], Train Accuracy: 0.8424, Test Accuracy: 0.7179
# Epoch [12/20], Train Accuracy: 0.8614, Test Accuracy: 0.6923
# Epoch [13/20], Train Accuracy: 0.8732, Test Accuracy: 0.7094
# Epoch [14/20], Train Accuracy: 0.8886, Test Accuracy: 0.6923
# Epoch [15/20], Train Accuracy: 0.8945, Test Accuracy: 0.7265
# Epoch [16/20], Train Accuracy: 0.9005, Test Accuracy: 0.7265
# Epoch [17/20], Train Accuracy: 0.9064, Test Accuracy: 0.7350
# Epoch [18/20], Train Accuracy: 0.9254, Test Accuracy: 0.7393
# Epoch [19/20], Train Accuracy: 0.9230, Test Accuracy: 0.7265
# Epoch [20/20], Train Accuracy: 0.9159, Test Accuracy: 0.7650
# Epoch [1/20], Train Accuracy: 0.7794, Test Accuracy: 0.8432
# Epoch [2/20], Train Accuracy: 0.7794, Test Accuracy: 0.8432
# Epoch [3/20], Train Accuracy: 0.7794, Test Accuracy: 0.8432
# Epoch [4/20], Train Accuracy: 0.7794, Test Accuracy: 0.8432
# Epoch [5/20], Train Accuracy: 0.7872, Test Accuracy: 0.7838
# Epoch [6/20], Train Accuracy: 0.7917, Test Accuracy: 0.7838
# Epoch [7/20], Train Accuracy: 0.8085, Test Accuracy: 0.7514
# Epoch [8/20], Train Accuracy: 0.8130, Test Accuracy: 0.7459
# Epoch [9/20], Train Accuracy: 0.8488, Test Accuracy: 0.7514
# Epoch [10/20], Train Accuracy: 0.8567, Test Accuracy: 0.7081
# Epoch [11/20], Train Accuracy: 0.8656, Test Accuracy: 0.7243
# Epoch [12/20], Train Accuracy: 0.8768, Test Accuracy: 0.7027
# Epoch [13/20], Train Accuracy: 0.8891, Test Accuracy: 0.7189
# Epoch [14/20], Train Accuracy: 0.8903, Test Accuracy: 0.7135
# Epoch [15/20], Train Accuracy: 0.8903, Test Accuracy: 0.7243
# Epoch [16/20], Train Accuracy: 0.9160, Test Accuracy: 0.7081
# Epoch [17/20], Train Accuracy: 0.9127, Test Accuracy: 0.7081
# Epoch [18/20], Train Accuracy: 0.9183, Test Accuracy: 0.7405
# Epoch [19/20], Train Accuracy: 0.9250, Test Accuracy: 0.7189
# Epoch [20/20], Train Accuracy: 0.9429, Test Accuracy: 0.6919
# Epoch [1/20], Train Accuracy: 0.7901, Test Accuracy: 0.7912
# Epoch [2/20], Train Accuracy: 0.7901, Test Accuracy: 0.7912
# Epoch [3/20], Train Accuracy: 0.7901, Test Accuracy: 0.7912
# Epoch [4/20], Train Accuracy: 0.7901, Test Accuracy: 0.7912
# Epoch [5/20], Train Accuracy: 0.7973, Test Accuracy: 0.7912
# Epoch [6/20], Train Accuracy: 0.8263, Test Accuracy: 0.7791
# Epoch [7/20], Train Accuracy: 0.8287, Test Accuracy: 0.7751
# Epoch [8/20], Train Accuracy: 0.8215, Test Accuracy: 0.7831
# Epoch [9/20], Train Accuracy: 0.8420, Test Accuracy: 0.7791
# Epoch [10/20], Train Accuracy: 0.8408, Test Accuracy: 0.7831
# Epoch [11/20], Train Accuracy: 0.8842, Test Accuracy: 0.7068
# Epoch [12/20], Train Accuracy: 0.9071, Test Accuracy: 0.7189
# Epoch [13/20], Train Accuracy: 0.9023, Test Accuracy: 0.6627
# Epoch [14/20], Train Accuracy: 0.8794, Test Accuracy: 0.7912
# Epoch [15/20], Train Accuracy: 0.9216, Test Accuracy: 0.6747
# Epoch [16/20], Train Accuracy: 0.9071, Test Accuracy: 0.6145
# Epoch [17/20], Train Accuracy: 0.9180, Test Accuracy: 0.6948
# Epoch [18/20], Train Accuracy: 0.9071, Test Accuracy: 0.7028
# Epoch [19/20], Train Accuracy: 0.9180, Test Accuracy: 0.7028
# Epoch [20/20], Train Accuracy: 0.9192, Test Accuracy: 0.6747
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.7919
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.7919
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.7919
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.7919
# Epoch [5/20], Train Accuracy: 0.8168, Test Accuracy: 0.7330
# Epoch [6/20], Train Accuracy: 0.8191, Test Accuracy: 0.7149
# Epoch [7/20], Train Accuracy: 0.8401, Test Accuracy: 0.7195
# Epoch [8/20], Train Accuracy: 0.8436, Test Accuracy: 0.7195
# Epoch [9/20], Train Accuracy: 0.8681, Test Accuracy: 0.7014
# Epoch [10/20], Train Accuracy: 0.8705, Test Accuracy: 0.7014
# Epoch [11/20], Train Accuracy: 0.8740, Test Accuracy: 0.6380
# Epoch [12/20], Train Accuracy: 0.8903, Test Accuracy: 0.6154
# Epoch [13/20], Train Accuracy: 0.8868, Test Accuracy: 0.6606
# Epoch [14/20], Train Accuracy: 0.9032, Test Accuracy: 0.6742
# Epoch [15/20], Train Accuracy: 0.9125, Test Accuracy: 0.6742
# Epoch [16/20], Train Accuracy: 0.9160, Test Accuracy: 0.6380
# Epoch [17/20], Train Accuracy: 0.9172, Test Accuracy: 0.6335
# Epoch [18/20], Train Accuracy: 0.9102, Test Accuracy: 0.6833
# Epoch [19/20], Train Accuracy: 0.9207, Test Accuracy: 0.6697
# Epoch [20/20], Train Accuracy: 0.9300, Test Accuracy: 0.6787
# Epoch [1/20], Train Accuracy: 0.7751, Test Accuracy: 0.8531
# Epoch [2/20], Train Accuracy: 0.7751, Test Accuracy: 0.8531
# Epoch [3/20], Train Accuracy: 0.7751, Test Accuracy: 0.8531
# Epoch [4/20], Train Accuracy: 0.7751, Test Accuracy: 0.8531
# Epoch [5/20], Train Accuracy: 0.7947, Test Accuracy: 0.8436
# Epoch [6/20], Train Accuracy: 0.7912, Test Accuracy: 0.8436
# Epoch [7/20], Train Accuracy: 0.8178, Test Accuracy: 0.7536
# Epoch [8/20], Train Accuracy: 0.8270, Test Accuracy: 0.7583
# Epoch [9/20], Train Accuracy: 0.8362, Test Accuracy: 0.7393
# Epoch [10/20], Train Accuracy: 0.8397, Test Accuracy: 0.7867
# Epoch [11/20], Train Accuracy: 0.8547, Test Accuracy: 0.7346
# Epoch [12/20], Train Accuracy: 0.8581, Test Accuracy: 0.7773
# Epoch [13/20], Train Accuracy: 0.8708, Test Accuracy: 0.7393
# Epoch [14/20], Train Accuracy: 0.8674, Test Accuracy: 0.8009
# Epoch [15/20], Train Accuracy: 0.8893, Test Accuracy: 0.7251
# Epoch [16/20], Train Accuracy: 0.8847, Test Accuracy: 0.7773
# Epoch [17/20], Train Accuracy: 0.9077, Test Accuracy: 0.7393
# Epoch [18/20], Train Accuracy: 0.8766, Test Accuracy: 0.8057
# Epoch [19/20], Train Accuracy: 0.9170, Test Accuracy: 0.7441
# Epoch [20/20], Train Accuracy: 0.9262, Test Accuracy: 0.7536
# Epoch [1/20], Train Accuracy: 0.8002, Test Accuracy: 0.7448
# Epoch [2/20], Train Accuracy: 0.8002, Test Accuracy: 0.7448
# Epoch [3/20], Train Accuracy: 0.8002, Test Accuracy: 0.7448
# Epoch [4/20], Train Accuracy: 0.8002, Test Accuracy: 0.7448
# Epoch [5/20], Train Accuracy: 0.8002, Test Accuracy: 0.7448
# Epoch [6/20], Train Accuracy: 0.8070, Test Accuracy: 0.7448
# Epoch [7/20], Train Accuracy: 0.8126, Test Accuracy: 0.7448
# Epoch [8/20], Train Accuracy: 0.8228, Test Accuracy: 0.7448
# Epoch [9/20], Train Accuracy: 0.8251, Test Accuracy: 0.7448
# Epoch [10/20], Train Accuracy: 0.8318, Test Accuracy: 0.7448
# Epoch [11/20], Train Accuracy: 0.8567, Test Accuracy: 0.7448
# Epoch [12/20], Train Accuracy: 0.8826, Test Accuracy: 0.7500
# Epoch [13/20], Train Accuracy: 0.8962, Test Accuracy: 0.7448
# Epoch [14/20], Train Accuracy: 0.9063, Test Accuracy: 0.7448
# Epoch [15/20], Train Accuracy: 0.9131, Test Accuracy: 0.7500
# Epoch [16/20], Train Accuracy: 0.9199, Test Accuracy: 0.7448
# Epoch [17/20], Train Accuracy: 0.9029, Test Accuracy: 0.7396
# Epoch [18/20], Train Accuracy: 0.9402, Test Accuracy: 0.7448
# Epoch [19/20], Train Accuracy: 0.9345, Test Accuracy: 0.7292
# Epoch [20/20], Train Accuracy: 0.9323, Test Accuracy: 0.7344
# Epoch [1/20], Train Accuracy: 0.7892, Test Accuracy: 0.7951
# Epoch [2/20], Train Accuracy: 0.7892, Test Accuracy: 0.7951
# Epoch [3/20], Train Accuracy: 0.7892, Test Accuracy: 0.7951
# Epoch [4/20], Train Accuracy: 0.7892, Test Accuracy: 0.7951
# Epoch [5/20], Train Accuracy: 0.7892, Test Accuracy: 0.7951
# Epoch [6/20], Train Accuracy: 0.8099, Test Accuracy: 0.7902
# Epoch [7/20], Train Accuracy: 0.8190, Test Accuracy: 0.7902
# Epoch [8/20], Train Accuracy: 0.8133, Test Accuracy: 0.7902
# Epoch [9/20], Train Accuracy: 0.8351, Test Accuracy: 0.7854
# Epoch [10/20], Train Accuracy: 0.8660, Test Accuracy: 0.7610
# Epoch [11/20], Train Accuracy: 0.8671, Test Accuracy: 0.7610
# Epoch [12/20], Train Accuracy: 0.8729, Test Accuracy: 0.7610
# Epoch [13/20], Train Accuracy: 0.8740, Test Accuracy: 0.7854
# Epoch [14/20], Train Accuracy: 0.8465, Test Accuracy: 0.7902
# Epoch [15/20], Train Accuracy: 0.8855, Test Accuracy: 0.7512
# Epoch [16/20], Train Accuracy: 0.8946, Test Accuracy: 0.7707
# Epoch [17/20], Train Accuracy: 0.9049, Test Accuracy: 0.7463
# Epoch [18/20], Train Accuracy: 0.9278, Test Accuracy: 0.6976
# Epoch [19/20], Train Accuracy: 0.9255, Test Accuracy: 0.6878
# Epoch [20/20], Train Accuracy: 0.9301, Test Accuracy: 0.6585
# Epoch [1/20], Train Accuracy: 0.7633, Test Accuracy: 0.8727
# Epoch [2/20], Train Accuracy: 0.7633, Test Accuracy: 0.8727
# Epoch [3/20], Train Accuracy: 0.7633, Test Accuracy: 0.8727
# Epoch [4/20], Train Accuracy: 0.7633, Test Accuracy: 0.8689
# Epoch [5/20], Train Accuracy: 0.7768, Test Accuracy: 0.7753
# Epoch [6/20], Train Accuracy: 0.8261, Test Accuracy: 0.6779
# Epoch [7/20], Train Accuracy: 0.8150, Test Accuracy: 0.6891
# Epoch [8/20], Train Accuracy: 0.8274, Test Accuracy: 0.6816
# Epoch [9/20], Train Accuracy: 0.8298, Test Accuracy: 0.6854
# Epoch [10/20], Train Accuracy: 0.8742, Test Accuracy: 0.6479
# Epoch [11/20], Train Accuracy: 0.8915, Test Accuracy: 0.6404
# Epoch [12/20], Train Accuracy: 0.8767, Test Accuracy: 0.6517
# Epoch [13/20], Train Accuracy: 0.9038, Test Accuracy: 0.6180
# Epoch [14/20], Train Accuracy: 0.9051, Test Accuracy: 0.6442
# Epoch [15/20], Train Accuracy: 0.9236, Test Accuracy: 0.6217
# Epoch [16/20], Train Accuracy: 0.9334, Test Accuracy: 0.6142
# Epoch [17/20], Train Accuracy: 0.9383, Test Accuracy: 0.6105
# Epoch [18/20], Train Accuracy: 0.9383, Test Accuracy: 0.6142
# Epoch [19/20], Train Accuracy: 0.9346, Test Accuracy: 0.6030
# Epoch [20/20], Train Accuracy: 0.9309, Test Accuracy: 0.6442
# Epoch [1/20], Train Accuracy: 0.8107, Test Accuracy: 0.6889
# Epoch [2/20], Train Accuracy: 0.8107, Test Accuracy: 0.6889
# Epoch [3/20], Train Accuracy: 0.8107, Test Accuracy: 0.6889
# Epoch [4/20], Train Accuracy: 0.8107, Test Accuracy: 0.6889
# Epoch [5/20], Train Accuracy: 0.8107, Test Accuracy: 0.6889
# Epoch [6/20], Train Accuracy: 0.8118, Test Accuracy: 0.6889
# Epoch [7/20], Train Accuracy: 0.8296, Test Accuracy: 0.6889
# Epoch [8/20], Train Accuracy: 0.8252, Test Accuracy: 0.6889
# Epoch [9/20], Train Accuracy: 0.8552, Test Accuracy: 0.6889
# Epoch [10/20], Train Accuracy: 0.8541, Test Accuracy: 0.6889
# Epoch [11/20], Train Accuracy: 0.8764, Test Accuracy: 0.6778
# Epoch [12/20], Train Accuracy: 0.8786, Test Accuracy: 0.6833
# Epoch [13/20], Train Accuracy: 0.9009, Test Accuracy: 0.6389
# Epoch [14/20], Train Accuracy: 0.9053, Test Accuracy: 0.6667
# Epoch [15/20], Train Accuracy: 0.9165, Test Accuracy: 0.6500
# Epoch [16/20], Train Accuracy: 0.9143, Test Accuracy: 0.6444
# Epoch [17/20], Train Accuracy: 0.9149, Test Accuracy: 0.6460
# Epoch [18/20], Train Accuracy: 0.9357, Test Accuracy: 0.6584
# Epoch [19/20], Train Accuracy: 0.9302, Test Accuracy: 0.6646
# Epoch [20/20], Train Accuracy: 0.9258, Test Accuracy: 0.6957
# Epoch [1/20], Train Accuracy: 0.8173, Test Accuracy: 0.6936
# Epoch [2/20], Train Accuracy: 0.8173, Test Accuracy: 0.6936
# Epoch [3/20], Train Accuracy: 0.8173, Test Accuracy: 0.6936
# Epoch [4/20], Train Accuracy: 0.8173, Test Accuracy: 0.6936
# Epoch [5/20], Train Accuracy: 0.8185, Test Accuracy: 0.6936
# Epoch [6/20], Train Accuracy: 0.8410, Test Accuracy: 0.6936
# Epoch [7/20], Train Accuracy: 0.8470, Test Accuracy: 0.6894
# Epoch [8/20], Train Accuracy: 0.8600, Test Accuracy: 0.6596
# Epoch [9/20], Train Accuracy: 0.8766, Test Accuracy: 0.6426
# Epoch [10/20], Train Accuracy: 0.8707, Test Accuracy: 0.6809
# Epoch [11/20], Train Accuracy: 0.8660, Test Accuracy: 0.6553
# Epoch [12/20], Train Accuracy: 0.8873, Test Accuracy: 0.6468
# Epoch [13/20], Train Accuracy: 0.8861, Test Accuracy: 0.6596
# Epoch [14/20], Train Accuracy: 0.8921, Test Accuracy: 0.6511
# Epoch [15/20], Train Accuracy: 0.8921, Test Accuracy: 0.6511
# Epoch [16/20], Train Accuracy: 0.9051, Test Accuracy: 0.6553
# Epoch [17/20], Train Accuracy: 0.9158, Test Accuracy: 0.6894
# Epoch [18/20], Train Accuracy: 0.9193, Test Accuracy: 0.6596
# Epoch [19/20], Train Accuracy: 0.9407, Test Accuracy: 0.6766
# Epoch [20/20], Train Accuracy: 0.9431, Test Accuracy: 0.6511
# Epoch [1/20], Train Accuracy: 0.7972, Test Accuracy: 0.7628
# Epoch [2/20], Train Accuracy: 0.7972, Test Accuracy: 0.7628
# Epoch [3/20], Train Accuracy: 0.7972, Test Accuracy: 0.7628
# Epoch [4/20], Train Accuracy: 0.7972, Test Accuracy: 0.7628
# Epoch [5/20], Train Accuracy: 0.7972, Test Accuracy: 0.7628
# Epoch [6/20], Train Accuracy: 0.7972, Test Accuracy: 0.7628
# Epoch [7/20], Train Accuracy: 0.7972, Test Accuracy: 0.7628
# Epoch [8/20], Train Accuracy: 0.7984, Test Accuracy: 0.7674
# Epoch [9/20], Train Accuracy: 0.8111, Test Accuracy: 0.7767
# Epoch [10/20], Train Accuracy: 0.8158, Test Accuracy: 0.7721
# Epoch [11/20], Train Accuracy: 0.8262, Test Accuracy: 0.7628
# Epoch [12/20], Train Accuracy: 0.8528, Test Accuracy: 0.6884
# Epoch [13/20], Train Accuracy: 0.8749, Test Accuracy: 0.6930
# Epoch [14/20], Train Accuracy: 0.8864, Test Accuracy: 0.6419
# Epoch [15/20], Train Accuracy: 0.8922, Test Accuracy: 0.6791
# Epoch [16/20], Train Accuracy: 0.8853, Test Accuracy: 0.7256
# Epoch [17/20], Train Accuracy: 0.9015, Test Accuracy: 0.6884
# Epoch [18/20], Train Accuracy: 0.8980, Test Accuracy: 0.7302
# Epoch [19/20], Train Accuracy: 0.9200, Test Accuracy: 0.6465
# Epoch [20/20], Train Accuracy: 0.9212, Test Accuracy: 0.7209
# Epoch [1/20], Train Accuracy: 0.7780, Test Accuracy: 0.8404
# Epoch [2/20], Train Accuracy: 0.7780, Test Accuracy: 0.8404
# Epoch [3/20], Train Accuracy: 0.7780, Test Accuracy: 0.8404
# Epoch [4/20], Train Accuracy: 0.7780, Test Accuracy: 0.8404
# Epoch [5/20], Train Accuracy: 0.7792, Test Accuracy: 0.8404
# Epoch [6/20], Train Accuracy: 0.7931, Test Accuracy: 0.8404
# Epoch [7/20], Train Accuracy: 0.8046, Test Accuracy: 0.8357
# Epoch [8/20], Train Accuracy: 0.8139, Test Accuracy: 0.7746
# Epoch [9/20], Train Accuracy: 0.8058, Test Accuracy: 0.8357
# Epoch [10/20], Train Accuracy: 0.8197, Test Accuracy: 0.7981
# Epoch [11/20], Train Accuracy: 0.8243, Test Accuracy: 0.7934
# Epoch [12/20], Train Accuracy: 0.8474, Test Accuracy: 0.6808
# Epoch [13/20], Train Accuracy: 0.8578, Test Accuracy: 0.6808
# Epoch [14/20], Train Accuracy: 0.8624, Test Accuracy: 0.6995
# Epoch [15/20], Train Accuracy: 0.8636, Test Accuracy: 0.6291
# Epoch [16/20], Train Accuracy: 0.8358, Test Accuracy: 0.7700
# Epoch [17/20], Train Accuracy: 0.8728, Test Accuracy: 0.6573
# Epoch [18/20], Train Accuracy: 0.8798, Test Accuracy: 0.6197
# Epoch [19/20], Train Accuracy: 0.8960, Test Accuracy: 0.6432
# Epoch [20/20], Train Accuracy: 0.8832, Test Accuracy: 0.6667
# Epoch [1/20], Train Accuracy: 0.7658, Test Accuracy: 0.8701
# Epoch [2/20], Train Accuracy: 0.7658, Test Accuracy: 0.8701
# Epoch [3/20], Train Accuracy: 0.7658, Test Accuracy: 0.8701
# Epoch [4/20], Train Accuracy: 0.7706, Test Accuracy: 0.8701
# Epoch [5/20], Train Accuracy: 0.7864, Test Accuracy: 0.8346
# Epoch [6/20], Train Accuracy: 0.7925, Test Accuracy: 0.7441
# Epoch [7/20], Train Accuracy: 0.8265, Test Accuracy: 0.6654
# Epoch [8/20], Train Accuracy: 0.8325, Test Accuracy: 0.6417
# Epoch [9/20], Train Accuracy: 0.8471, Test Accuracy: 0.6575
# Epoch [10/20], Train Accuracy: 0.8447, Test Accuracy: 0.6811
# Epoch [11/20], Train Accuracy: 0.8714, Test Accuracy: 0.6260
# Epoch [12/20], Train Accuracy: 0.8726, Test Accuracy: 0.6535
# Epoch [13/20], Train Accuracy: 0.8847, Test Accuracy: 0.6654
# Epoch [14/20], Train Accuracy: 0.9066, Test Accuracy: 0.6417
# Epoch [15/20], Train Accuracy: 0.8956, Test Accuracy: 0.6929
# Epoch [16/20], Train Accuracy: 0.9066, Test Accuracy: 0.5827
# Epoch [17/20], Train Accuracy: 0.9272, Test Accuracy: 0.5984
# Epoch [18/20], Train Accuracy: 0.9017, Test Accuracy: 0.7047
# Epoch [19/20], Train Accuracy: 0.9296, Test Accuracy: 0.6142
# Epoch [20/20], Train Accuracy: 0.9211, Test Accuracy: 0.5472
# Epoch [1/20], Train Accuracy: 0.7686, Test Accuracy: 0.8906
# Epoch [2/20], Train Accuracy: 0.7686, Test Accuracy: 0.8906
# Epoch [3/20], Train Accuracy: 0.7686, Test Accuracy: 0.8906
# Epoch [4/20], Train Accuracy: 0.7686, Test Accuracy: 0.8906
# Epoch [5/20], Train Accuracy: 0.7709, Test Accuracy: 0.8906
# Epoch [6/20], Train Accuracy: 0.7731, Test Accuracy: 0.8750
# Epoch [7/20], Train Accuracy: 0.7923, Test Accuracy: 0.8333
# Epoch [8/20], Train Accuracy: 0.8138, Test Accuracy: 0.8281
# Epoch [9/20], Train Accuracy: 0.8160, Test Accuracy: 0.8177
# Epoch [10/20], Train Accuracy: 0.8713, Test Accuracy: 0.7344
# Epoch [11/20], Train Accuracy: 0.8589, Test Accuracy: 0.7865
# Epoch [12/20], Train Accuracy: 0.8747, Test Accuracy: 0.7917
# Epoch [13/20], Train Accuracy: 0.8725, Test Accuracy: 0.7969
# Epoch [14/20], Train Accuracy: 0.8984, Test Accuracy: 0.7500
# Epoch [15/20], Train Accuracy: 0.9052, Test Accuracy: 0.7708
# Epoch [16/20], Train Accuracy: 0.9108, Test Accuracy: 0.7812
# Epoch [17/20], Train Accuracy: 0.9199, Test Accuracy: 0.7812
# Epoch [18/20], Train Accuracy: 0.9221, Test Accuracy: 0.7292
# Epoch [19/20], Train Accuracy: 0.9221, Test Accuracy: 0.7292
# Epoch [20/20], Train Accuracy: 0.9153, Test Accuracy: 0.7969
# Epoch [1/20], Train Accuracy: 0.7810, Test Accuracy: 0.8219
# Epoch [2/20], Train Accuracy: 0.7810, Test Accuracy: 0.8219
# Epoch [3/20], Train Accuracy: 0.7810, Test Accuracy: 0.8219
# Epoch [4/20], Train Accuracy: 0.7810, Test Accuracy: 0.8219
# Epoch [5/20], Train Accuracy: 0.7810, Test Accuracy: 0.8219
# Epoch [6/20], Train Accuracy: 0.8002, Test Accuracy: 0.8219
# Epoch [7/20], Train Accuracy: 0.8171, Test Accuracy: 0.7652
# Epoch [8/20], Train Accuracy: 0.8087, Test Accuracy: 0.8097
# Epoch [9/20], Train Accuracy: 0.8207, Test Accuracy: 0.7733
# Epoch [10/20], Train Accuracy: 0.8460, Test Accuracy: 0.7449
# Epoch [11/20], Train Accuracy: 0.8424, Test Accuracy: 0.7490
# Epoch [12/20], Train Accuracy: 0.8520, Test Accuracy: 0.7004
# Epoch [13/20], Train Accuracy: 0.8604, Test Accuracy: 0.7126
# Epoch [14/20], Train Accuracy: 0.8604, Test Accuracy: 0.7895
# Epoch [15/20], Train Accuracy: 0.8652, Test Accuracy: 0.7773
# Epoch [16/20], Train Accuracy: 0.8869, Test Accuracy: 0.7652
# Epoch [17/20], Train Accuracy: 0.9001, Test Accuracy: 0.7409
# Epoch [18/20], Train Accuracy: 0.9013, Test Accuracy: 0.7652
# Epoch [19/20], Train Accuracy: 0.9073, Test Accuracy: 0.7652
# Epoch [20/20], Train Accuracy: 0.9061, Test Accuracy: 0.7692
# Epoch [1/20], Train Accuracy: 0.8049, Test Accuracy: 0.7204
# Epoch [2/20], Train Accuracy: 0.8049, Test Accuracy: 0.7204
# Epoch [3/20], Train Accuracy: 0.8049, Test Accuracy: 0.7204
# Epoch [4/20], Train Accuracy: 0.8049, Test Accuracy: 0.7204
# Epoch [5/20], Train Accuracy: 0.8049, Test Accuracy: 0.7204
# Epoch [6/20], Train Accuracy: 0.8083, Test Accuracy: 0.7204
# Epoch [7/20], Train Accuracy: 0.8374, Test Accuracy: 0.6505
# Epoch [8/20], Train Accuracy: 0.8464, Test Accuracy: 0.6452
# Epoch [9/20], Train Accuracy: 0.8554, Test Accuracy: 0.6559
# Epoch [10/20], Train Accuracy: 0.8543, Test Accuracy: 0.6022
# Epoch [11/20], Train Accuracy: 0.8756, Test Accuracy: 0.6183
# Epoch [12/20], Train Accuracy: 0.8722, Test Accuracy: 0.5806
# Epoch [13/20], Train Accuracy: 0.8946, Test Accuracy: 0.5914
# Epoch [14/20], Train Accuracy: 0.8924, Test Accuracy: 0.5753
# Epoch [15/20], Train Accuracy: 0.9047, Test Accuracy: 0.5591
# Epoch [16/20], Train Accuracy: 0.9182, Test Accuracy: 0.5699
# Epoch [17/20], Train Accuracy: 0.9148, Test Accuracy: 0.5376
# Epoch [18/20], Train Accuracy: 0.9193, Test Accuracy: 0.5430
# Epoch [19/20], Train Accuracy: 0.9114, Test Accuracy: 0.6075
# Epoch [20/20], Train Accuracy: 0.9204, Test Accuracy: 0.5591
# Epoch [1/20], Train Accuracy: 0.7855, Test Accuracy: 0.8089
# Epoch [2/20], Train Accuracy: 0.7855, Test Accuracy: 0.8089
# Epoch [3/20], Train Accuracy: 0.7855, Test Accuracy: 0.8089
# Epoch [4/20], Train Accuracy: 0.7855, Test Accuracy: 0.8089
# Epoch [5/20], Train Accuracy: 0.7855, Test Accuracy: 0.8044
# Epoch [6/20], Train Accuracy: 0.7984, Test Accuracy: 0.7600
# Epoch [7/20], Train Accuracy: 0.8159, Test Accuracy: 0.7333
# Epoch [8/20], Train Accuracy: 0.8382, Test Accuracy: 0.6844
# Epoch [9/20], Train Accuracy: 0.8382, Test Accuracy: 0.7289
# Epoch [10/20], Train Accuracy: 0.8429, Test Accuracy: 0.7111
# Epoch [11/20], Train Accuracy: 0.8839, Test Accuracy: 0.6667
# Epoch [12/20], Train Accuracy: 0.9062, Test Accuracy: 0.6844
# Epoch [13/20], Train Accuracy: 0.9132, Test Accuracy: 0.6578
# Epoch [14/20], Train Accuracy: 0.9109, Test Accuracy: 0.5911
# Epoch [15/20], Train Accuracy: 0.9156, Test Accuracy: 0.5556
# Epoch [16/20], Train Accuracy: 0.9250, Test Accuracy: 0.6978
# Epoch [17/20], Train Accuracy: 0.9461, Test Accuracy: 0.6222
# Epoch [18/20], Train Accuracy: 0.9437, Test Accuracy: 0.6400
# Epoch [19/20], Train Accuracy: 0.9355, Test Accuracy: 0.6800
# Epoch [20/20], Train Accuracy: 0.9426, Test Accuracy: 0.6978
# Epoch [1/20], Train Accuracy: 0.8118, Test Accuracy: 0.7105
# Epoch [2/20], Train Accuracy: 0.8118, Test Accuracy: 0.7105
# Epoch [3/20], Train Accuracy: 0.8118, Test Accuracy: 0.7105
# Epoch [4/20], Train Accuracy: 0.8118, Test Accuracy: 0.7105
# Epoch [5/20], Train Accuracy: 0.8118, Test Accuracy: 0.7105
# Epoch [6/20], Train Accuracy: 0.8153, Test Accuracy: 0.7105
# Epoch [7/20], Train Accuracy: 0.8459, Test Accuracy: 0.7018
# Epoch [8/20], Train Accuracy: 0.8424, Test Accuracy: 0.6930
# Epoch [9/20], Train Accuracy: 0.8541, Test Accuracy: 0.6711
# Epoch [10/20], Train Accuracy: 0.8682, Test Accuracy: 0.6623
# Epoch [11/20], Train Accuracy: 0.8824, Test Accuracy: 0.6491
# Epoch [12/20], Train Accuracy: 0.8847, Test Accuracy: 0.6491
# Epoch [13/20], Train Accuracy: 0.8859, Test Accuracy: 0.6667
# Epoch [14/20], Train Accuracy: 0.9035, Test Accuracy: 0.6930
# Epoch [15/20], Train Accuracy: 0.9035, Test Accuracy: 0.6886
# Epoch [16/20], Train Accuracy: 0.8976, Test Accuracy: 0.6842
# Epoch [17/20], Train Accuracy: 0.9106, Test Accuracy: 0.6842
# Epoch [18/20], Train Accuracy: 0.9153, Test Accuracy: 0.7018
# Epoch [19/20], Train Accuracy: 0.9188, Test Accuracy: 0.7018
# Epoch [20/20], Train Accuracy: 0.9106, Test Accuracy: 0.7018
# Epoch [1/20], Train Accuracy: 0.7901, Test Accuracy: 0.7917
# Epoch [2/20], Train Accuracy: 0.7901, Test Accuracy: 0.7917
# Epoch [3/20], Train Accuracy: 0.7901, Test Accuracy: 0.7917
# Epoch [4/20], Train Accuracy: 0.7901, Test Accuracy: 0.7917
# Epoch [5/20], Train Accuracy: 0.7889, Test Accuracy: 0.7917
# Epoch [6/20], Train Accuracy: 0.7935, Test Accuracy: 0.7917
# Epoch [7/20], Train Accuracy: 0.8036, Test Accuracy: 0.7917
# Epoch [8/20], Train Accuracy: 0.8014, Test Accuracy: 0.7917
# Epoch [9/20], Train Accuracy: 0.7968, Test Accuracy: 0.7917
# Epoch [10/20], Train Accuracy: 0.8262, Test Accuracy: 0.7917
# Epoch [11/20], Train Accuracy: 0.8510, Test Accuracy: 0.7917
# Epoch [12/20], Train Accuracy: 0.8691, Test Accuracy: 0.7708
# Epoch [13/20], Train Accuracy: 0.8578, Test Accuracy: 0.7917
# Epoch [14/20], Train Accuracy: 0.8758, Test Accuracy: 0.7760
# Epoch [15/20], Train Accuracy: 0.8916, Test Accuracy: 0.7812
# Epoch [16/20], Train Accuracy: 0.8973, Test Accuracy: 0.7604
# Epoch [17/20], Train Accuracy: 0.9074, Test Accuracy: 0.7292
# Epoch [18/20], Train Accuracy: 0.9199, Test Accuracy: 0.7552
# Epoch [19/20], Train Accuracy: 0.9131, Test Accuracy: 0.6927
# Epoch [20/20], Train Accuracy: 0.9244, Test Accuracy: 0.7760
# Epoch [1/20], Train Accuracy: 0.7740, Test Accuracy: 0.8558
# Epoch [2/20], Train Accuracy: 0.7740, Test Accuracy: 0.8558
# Epoch [3/20], Train Accuracy: 0.7740, Test Accuracy: 0.8558
# Epoch [4/20], Train Accuracy: 0.7740, Test Accuracy: 0.8558
# Epoch [5/20], Train Accuracy: 0.7729, Test Accuracy: 0.8558
# Epoch [6/20], Train Accuracy: 0.7752, Test Accuracy: 0.8558
# Epoch [7/20], Train Accuracy: 0.8088, Test Accuracy: 0.8512
# Epoch [8/20], Train Accuracy: 0.8100, Test Accuracy: 0.8419
# Epoch [9/20], Train Accuracy: 0.8262, Test Accuracy: 0.7814
# Epoch [10/20], Train Accuracy: 0.8273, Test Accuracy: 0.7767
# Epoch [11/20], Train Accuracy: 0.8540, Test Accuracy: 0.7395
# Epoch [12/20], Train Accuracy: 0.8575, Test Accuracy: 0.7349
# Epoch [13/20], Train Accuracy: 0.8633, Test Accuracy: 0.7395
# Epoch [14/20], Train Accuracy: 0.8795, Test Accuracy: 0.7209
# Epoch [15/20], Train Accuracy: 0.8992, Test Accuracy: 0.7023
# Epoch [16/20], Train Accuracy: 0.8957, Test Accuracy: 0.7023
# Epoch [17/20], Train Accuracy: 0.9003, Test Accuracy: 0.6884
# Epoch [18/20], Train Accuracy: 0.9189, Test Accuracy: 0.6884
# Epoch [19/20], Train Accuracy: 0.9235, Test Accuracy: 0.6884
# Epoch [20/20], Train Accuracy: 0.9224, Test Accuracy: 0.6930
# Epoch [1/20], Train Accuracy: 0.7937, Test Accuracy: 0.7697
# Epoch [2/20], Train Accuracy: 0.7937, Test Accuracy: 0.7697
# Epoch [3/20], Train Accuracy: 0.7937, Test Accuracy: 0.7697
# Epoch [4/20], Train Accuracy: 0.7937, Test Accuracy: 0.7697
# Epoch [5/20], Train Accuracy: 0.7937, Test Accuracy: 0.7697
# Epoch [6/20], Train Accuracy: 0.7937, Test Accuracy: 0.7697
# Epoch [7/20], Train Accuracy: 0.8024, Test Accuracy: 0.7697
# Epoch [8/20], Train Accuracy: 0.8251, Test Accuracy: 0.7697
# Epoch [9/20], Train Accuracy: 0.8477, Test Accuracy: 0.7697
# Epoch [10/20], Train Accuracy: 0.8510, Test Accuracy: 0.7697
# Epoch [11/20], Train Accuracy: 0.8639, Test Accuracy: 0.7697
# Epoch [12/20], Train Accuracy: 0.8931, Test Accuracy: 0.7500
# Epoch [13/20], Train Accuracy: 0.8985, Test Accuracy: 0.7500
# Epoch [14/20], Train Accuracy: 0.8715, Test Accuracy: 0.7763
# Epoch [15/20], Train Accuracy: 0.8952, Test Accuracy: 0.7434
# Epoch [16/20], Train Accuracy: 0.9287, Test Accuracy: 0.7171
# Epoch [17/20], Train Accuracy: 0.9352, Test Accuracy: 0.7434
# Epoch [18/20], Train Accuracy: 0.9125, Test Accuracy: 0.7434
# Epoch [19/20], Train Accuracy: 0.9222, Test Accuracy: 0.7632
# Epoch [20/20], Train Accuracy: 0.9514, Test Accuracy: 0.7303
# Epoch [1/20], Train Accuracy: 0.7827, Test Accuracy: 0.8163
# Epoch [2/20], Train Accuracy: 0.7827, Test Accuracy: 0.8163
# Epoch [3/20], Train Accuracy: 0.7827, Test Accuracy: 0.8163
# Epoch [4/20], Train Accuracy: 0.7911, Test Accuracy: 0.8000
# Epoch [5/20], Train Accuracy: 0.7899, Test Accuracy: 0.7878
# Epoch [6/20], Train Accuracy: 0.8067, Test Accuracy: 0.7265
# Epoch [7/20], Train Accuracy: 0.8175, Test Accuracy: 0.6816
# Epoch [8/20], Train Accuracy: 0.8139, Test Accuracy: 0.7061
# Epoch [9/20], Train Accuracy: 0.8127, Test Accuracy: 0.6980
# Epoch [10/20], Train Accuracy: 0.8079, Test Accuracy: 0.6408
# Epoch [11/20], Train Accuracy: 0.8115, Test Accuracy: 0.6898
# Epoch [12/20], Train Accuracy: 0.8175, Test Accuracy: 0.6694
# Epoch [13/20], Train Accuracy: 0.8259, Test Accuracy: 0.6776
# Epoch [14/20], Train Accuracy: 0.8367, Test Accuracy: 0.6694
# Epoch [15/20], Train Accuracy: 0.8559, Test Accuracy: 0.6245
# Epoch [16/20], Train Accuracy: 0.8499, Test Accuracy: 0.6531
# Epoch [17/20], Train Accuracy: 0.8691, Test Accuracy: 0.6449
# Epoch [18/20], Train Accuracy: 0.8667, Test Accuracy: 0.6327
# Epoch [19/20], Train Accuracy: 0.8703, Test Accuracy: 0.6571
# Epoch [20/20], Train Accuracy: 0.8667, Test Accuracy: 0.6653
# Epoch [1/20], Train Accuracy: 0.8122, Test Accuracy: 0.7263
# Epoch [2/20], Train Accuracy: 0.8122, Test Accuracy: 0.7263
# Epoch [3/20], Train Accuracy: 0.8122, Test Accuracy: 0.7263
# Epoch [4/20], Train Accuracy: 0.8122, Test Accuracy: 0.7263
# Epoch [5/20], Train Accuracy: 0.8122, Test Accuracy: 0.7263
# Epoch [6/20], Train Accuracy: 0.8122, Test Accuracy: 0.7263
# Epoch [7/20], Train Accuracy: 0.8122, Test Accuracy: 0.7263
# Epoch [8/20], Train Accuracy: 0.8122, Test Accuracy: 0.7263
# Epoch [9/20], Train Accuracy: 0.8147, Test Accuracy: 0.7263
# Epoch [10/20], Train Accuracy: 0.8507, Test Accuracy: 0.7080
# Epoch [11/20], Train Accuracy: 0.8582, Test Accuracy: 0.7007
# Epoch [12/20], Train Accuracy: 0.8619, Test Accuracy: 0.7190
# Epoch [13/20], Train Accuracy: 0.8968, Test Accuracy: 0.6715
# Epoch [14/20], Train Accuracy: 0.9005, Test Accuracy: 0.6642
# Epoch [15/20], Train Accuracy: 0.9179, Test Accuracy: 0.6606
# Epoch [16/20], Train Accuracy: 0.9154, Test Accuracy: 0.6533
# Epoch [17/20], Train Accuracy: 0.9254, Test Accuracy: 0.6423
# Epoch [18/20], Train Accuracy: 0.9316, Test Accuracy: 0.6423
# Epoch [19/20], Train Accuracy: 0.9254, Test Accuracy: 0.6095
# Epoch [20/20], Train Accuracy: 0.9353, Test Accuracy: 0.6204
# Epoch [1/20], Train Accuracy: 0.8179, Test Accuracy: 0.6988
# Epoch [2/20], Train Accuracy: 0.8179, Test Accuracy: 0.6988
# Epoch [3/20], Train Accuracy: 0.8179, Test Accuracy: 0.6988
# Epoch [4/20], Train Accuracy: 0.8179, Test Accuracy: 0.6988
# Epoch [5/20], Train Accuracy: 0.8179, Test Accuracy: 0.6988
# Epoch [6/20], Train Accuracy: 0.8179, Test Accuracy: 0.6988
# Epoch [7/20], Train Accuracy: 0.8263, Test Accuracy: 0.6988
# Epoch [8/20], Train Accuracy: 0.8528, Test Accuracy: 0.6827
# Epoch [9/20], Train Accuracy: 0.8468, Test Accuracy: 0.6787
# Epoch [10/20], Train Accuracy: 0.8444, Test Accuracy: 0.6827
# Epoch [11/20], Train Accuracy: 0.8733, Test Accuracy: 0.6707
# Epoch [12/20], Train Accuracy: 0.8782, Test Accuracy: 0.6707
# Epoch [13/20], Train Accuracy: 0.9059, Test Accuracy: 0.6586
# Epoch [14/20], Train Accuracy: 0.9047, Test Accuracy: 0.6426
# Epoch [15/20], Train Accuracy: 0.9168, Test Accuracy: 0.6546
# Epoch [16/20], Train Accuracy: 0.8890, Test Accuracy: 0.6948
# Epoch [17/20], Train Accuracy: 0.9204, Test Accuracy: 0.6506
# Epoch [18/20], Train Accuracy: 0.9228, Test Accuracy: 0.6386
# Epoch [19/20], Train Accuracy: 0.9276, Test Accuracy: 0.6586
# Epoch [20/20], Train Accuracy: 0.9264, Test Accuracy: 0.5984
# Epoch [1/20], Train Accuracy: 0.8137, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.8137, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.8137, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.8137, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.8137, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.8170, Test Accuracy: 0.6667
# Epoch [7/20], Train Accuracy: 0.8335, Test Accuracy: 0.6667
# Epoch [8/20], Train Accuracy: 0.8467, Test Accuracy: 0.6667
# Epoch [9/20], Train Accuracy: 0.8567, Test Accuracy: 0.6491
# Epoch [10/20], Train Accuracy: 0.8666, Test Accuracy: 0.6433
# Epoch [11/20], Train Accuracy: 0.8842, Test Accuracy: 0.6023
# Epoch [12/20], Train Accuracy: 0.8931, Test Accuracy: 0.6491
# Epoch [13/20], Train Accuracy: 0.9085, Test Accuracy: 0.6082
# Epoch [14/20], Train Accuracy: 0.9118, Test Accuracy: 0.6140
# Epoch [15/20], Train Accuracy: 0.8964, Test Accuracy: 0.6608
# Epoch [16/20], Train Accuracy: 0.9096, Test Accuracy: 0.6491
# Epoch [17/20], Train Accuracy: 0.9261, Test Accuracy: 0.6257
# Epoch [18/20], Train Accuracy: 0.9372, Test Accuracy: 0.5906
# Epoch [19/20], Train Accuracy: 0.9372, Test Accuracy: 0.5965
# Epoch [20/20], Train Accuracy: 0.9350, Test Accuracy: 0.6199
# Epoch [1/20], Train Accuracy: 0.7745, Test Accuracy: 0.8600
# Epoch [2/20], Train Accuracy: 0.7745, Test Accuracy: 0.8600
# Epoch [3/20], Train Accuracy: 0.7745, Test Accuracy: 0.8600
# Epoch [4/20], Train Accuracy: 0.7745, Test Accuracy: 0.8600
# Epoch [5/20], Train Accuracy: 0.7825, Test Accuracy: 0.8150
# Epoch [6/20], Train Accuracy: 0.7847, Test Accuracy: 0.8250
# Epoch [7/20], Train Accuracy: 0.7916, Test Accuracy: 0.8100
# Epoch [8/20], Train Accuracy: 0.8383, Test Accuracy: 0.7250
# Epoch [9/20], Train Accuracy: 0.8405, Test Accuracy: 0.7050
# Epoch [10/20], Train Accuracy: 0.8588, Test Accuracy: 0.6750
# Epoch [11/20], Train Accuracy: 0.8599, Test Accuracy: 0.7150
# Epoch [12/20], Train Accuracy: 0.8781, Test Accuracy: 0.6600
# Epoch [13/20], Train Accuracy: 0.9112, Test Accuracy: 0.6500
# Epoch [14/20], Train Accuracy: 0.9100, Test Accuracy: 0.6250
# Epoch [15/20], Train Accuracy: 0.9237, Test Accuracy: 0.6100
# Epoch [16/20], Train Accuracy: 0.9055, Test Accuracy: 0.6750
# Epoch [17/20], Train Accuracy: 0.8907, Test Accuracy: 0.7100
# Epoch [18/20], Train Accuracy: 0.9328, Test Accuracy: 0.6550
# Epoch [19/20], Train Accuracy: 0.9282, Test Accuracy: 0.6300
# Epoch [20/20], Train Accuracy: 0.9396, Test Accuracy: 0.6550
# Epoch [1/20], Train Accuracy: 0.7924, Test Accuracy: 0.7838
# Epoch [2/20], Train Accuracy: 0.7924, Test Accuracy: 0.7838
# Epoch [3/20], Train Accuracy: 0.7924, Test Accuracy: 0.7838
# Epoch [4/20], Train Accuracy: 0.7924, Test Accuracy: 0.7838
# Epoch [5/20], Train Accuracy: 0.7924, Test Accuracy: 0.7838
# Epoch [6/20], Train Accuracy: 0.7924, Test Accuracy: 0.7838
# Epoch [7/20], Train Accuracy: 0.7924, Test Accuracy: 0.7838
# Epoch [8/20], Train Accuracy: 0.8046, Test Accuracy: 0.7722
# Epoch [9/20], Train Accuracy: 0.8168, Test Accuracy: 0.7645
# Epoch [10/20], Train Accuracy: 0.8400, Test Accuracy: 0.7259
# Epoch [11/20], Train Accuracy: 0.8449, Test Accuracy: 0.7490
# Epoch [12/20], Train Accuracy: 0.8559, Test Accuracy: 0.7490
# Epoch [13/20], Train Accuracy: 0.8767, Test Accuracy: 0.7452
# Epoch [14/20], Train Accuracy: 0.8791, Test Accuracy: 0.6795
# Epoch [15/20], Train Accuracy: 0.8852, Test Accuracy: 0.7375
# Epoch [16/20], Train Accuracy: 0.8950, Test Accuracy: 0.7375
# Epoch [17/20], Train Accuracy: 0.8803, Test Accuracy: 0.7683
# Epoch [18/20], Train Accuracy: 0.9084, Test Accuracy: 0.7606
# Epoch [19/20], Train Accuracy: 0.9158, Test Accuracy: 0.7027
# Epoch [20/20], Train Accuracy: 0.9292, Test Accuracy: 0.7066
# Epoch [1/20], Train Accuracy: 0.7543, Test Accuracy: 0.9497
# Epoch [2/20], Train Accuracy: 0.7543, Test Accuracy: 0.9497
# Epoch [3/20], Train Accuracy: 0.7543, Test Accuracy: 0.9497
# Epoch [4/20], Train Accuracy: 0.7543, Test Accuracy: 0.9497
# Epoch [5/20], Train Accuracy: 0.7543, Test Accuracy: 0.9497
# Epoch [6/20], Train Accuracy: 0.7770, Test Accuracy: 0.9347
# Epoch [7/20], Train Accuracy: 0.7770, Test Accuracy: 0.9347
# Epoch [8/20], Train Accuracy: 0.8168, Test Accuracy: 0.9045
# Epoch [9/20], Train Accuracy: 0.8294, Test Accuracy: 0.8844
# Epoch [10/20], Train Accuracy: 0.8305, Test Accuracy: 0.8844
# Epoch [11/20], Train Accuracy: 0.8407, Test Accuracy: 0.8844
# Epoch [12/20], Train Accuracy: 0.8726, Test Accuracy: 0.8794
# Epoch [13/20], Train Accuracy: 0.8942, Test Accuracy: 0.8342
# Epoch [14/20], Train Accuracy: 0.8840, Test Accuracy: 0.8844
# Epoch [15/20], Train Accuracy: 0.9170, Test Accuracy: 0.8492
# Epoch [16/20], Train Accuracy: 0.9101, Test Accuracy: 0.8744
# Epoch [17/20], Train Accuracy: 0.9033, Test Accuracy: 0.8844
# Epoch [18/20], Train Accuracy: 0.9363, Test Accuracy: 0.8241
# Epoch [19/20], Train Accuracy: 0.9363, Test Accuracy: 0.8291
# Epoch [20/20], Train Accuracy: 0.9408, Test Accuracy: 0.8191
# Epoch [1/20], Train Accuracy: 0.7740, Test Accuracy: 0.8558
# Epoch [2/20], Train Accuracy: 0.7740, Test Accuracy: 0.8558
# Epoch [3/20], Train Accuracy: 0.7740, Test Accuracy: 0.8558
# Epoch [4/20], Train Accuracy: 0.7740, Test Accuracy: 0.8558
# Epoch [5/20], Train Accuracy: 0.7740, Test Accuracy: 0.8558
# Epoch [6/20], Train Accuracy: 0.7787, Test Accuracy: 0.8465
# Epoch [7/20], Train Accuracy: 0.8088, Test Accuracy: 0.7907
# Epoch [8/20], Train Accuracy: 0.8053, Test Accuracy: 0.8000
# Epoch [9/20], Train Accuracy: 0.8320, Test Accuracy: 0.7721
# Epoch [10/20], Train Accuracy: 0.8436, Test Accuracy: 0.7860
# Epoch [11/20], Train Accuracy: 0.8586, Test Accuracy: 0.7814
# Epoch [12/20], Train Accuracy: 0.8679, Test Accuracy: 0.7721
# Epoch [13/20], Train Accuracy: 0.8760, Test Accuracy: 0.7907
# Epoch [14/20], Train Accuracy: 0.8888, Test Accuracy: 0.7581
# Epoch [15/20], Train Accuracy: 0.8946, Test Accuracy: 0.7581
# Epoch [16/20], Train Accuracy: 0.9166, Test Accuracy: 0.7442
# Epoch [17/20], Train Accuracy: 0.8980, Test Accuracy: 0.7814
# Epoch [18/20], Train Accuracy: 0.9258, Test Accuracy: 0.7395
# Epoch [19/20], Train Accuracy: 0.9316, Test Accuracy: 0.7256
# Epoch [20/20], Train Accuracy: 0.9189, Test Accuracy: 0.7814
# Epoch [1/20], Train Accuracy: 0.8119, Test Accuracy: 0.6895
# Epoch [2/20], Train Accuracy: 0.8119, Test Accuracy: 0.6895
# Epoch [3/20], Train Accuracy: 0.8119, Test Accuracy: 0.6895
# Epoch [4/20], Train Accuracy: 0.8119, Test Accuracy: 0.6895
# Epoch [5/20], Train Accuracy: 0.8131, Test Accuracy: 0.6895
# Epoch [6/20], Train Accuracy: 0.8164, Test Accuracy: 0.6895
# Epoch [7/20], Train Accuracy: 0.8187, Test Accuracy: 0.6789
# Epoch [8/20], Train Accuracy: 0.8187, Test Accuracy: 0.6526
# Epoch [9/20], Train Accuracy: 0.8288, Test Accuracy: 0.6368
# Epoch [10/20], Train Accuracy: 0.8300, Test Accuracy: 0.6316
# Epoch [11/20], Train Accuracy: 0.8502, Test Accuracy: 0.6316
# Epoch [12/20], Train Accuracy: 0.8795, Test Accuracy: 0.6053
# Epoch [13/20], Train Accuracy: 0.8874, Test Accuracy: 0.6000
# Epoch [14/20], Train Accuracy: 0.8986, Test Accuracy: 0.5684
# Epoch [15/20], Train Accuracy: 0.8953, Test Accuracy: 0.6053
# Epoch [16/20], Train Accuracy: 0.9110, Test Accuracy: 0.6474
# Epoch [17/20], Train Accuracy: 0.9144, Test Accuracy: 0.5789
# Epoch [18/20], Train Accuracy: 0.9268, Test Accuracy: 0.6053
# Epoch [19/20], Train Accuracy: 0.9268, Test Accuracy: 0.6895
# Epoch [20/20], Train Accuracy: 0.9426, Test Accuracy: 0.6263
# Epoch [1/20], Train Accuracy: 0.7930, Test Accuracy: 0.7798
# Epoch [2/20], Train Accuracy: 0.7930, Test Accuracy: 0.7798
# Epoch [3/20], Train Accuracy: 0.7930, Test Accuracy: 0.7798
# Epoch [4/20], Train Accuracy: 0.8081, Test Accuracy: 0.7798
# Epoch [5/20], Train Accuracy: 0.8128, Test Accuracy: 0.7615
# Epoch [6/20], Train Accuracy: 0.8233, Test Accuracy: 0.7064
# Epoch [7/20], Train Accuracy: 0.8337, Test Accuracy: 0.6927
# Epoch [8/20], Train Accuracy: 0.8337, Test Accuracy: 0.7064
# Epoch [9/20], Train Accuracy: 0.8523, Test Accuracy: 0.7018
# Epoch [10/20], Train Accuracy: 0.8570, Test Accuracy: 0.7202
# Epoch [11/20], Train Accuracy: 0.8709, Test Accuracy: 0.7202
# Epoch [12/20], Train Accuracy: 0.8698, Test Accuracy: 0.7385
# Epoch [13/20], Train Accuracy: 0.8930, Test Accuracy: 0.7110
# Epoch [14/20], Train Accuracy: 0.9012, Test Accuracy: 0.7202
# Epoch [15/20], Train Accuracy: 0.8814, Test Accuracy: 0.7248
# Epoch [16/20], Train Accuracy: 0.9256, Test Accuracy: 0.6835
# Epoch [17/20], Train Accuracy: 0.9174, Test Accuracy: 0.7431
# Epoch [18/20], Train Accuracy: 0.9244, Test Accuracy: 0.6743
# Epoch [19/20], Train Accuracy: 0.9209, Test Accuracy: 0.7156
# Epoch [20/20], Train Accuracy: 0.9198, Test Accuracy: 0.7248
# Epoch [1/20], Train Accuracy: 0.7957, Test Accuracy: 0.7712
# Epoch [2/20], Train Accuracy: 0.7957, Test Accuracy: 0.7712
# Epoch [3/20], Train Accuracy: 0.7957, Test Accuracy: 0.7712
# Epoch [4/20], Train Accuracy: 0.7957, Test Accuracy: 0.7712
# Epoch [5/20], Train Accuracy: 0.7957, Test Accuracy: 0.7712
# Epoch [6/20], Train Accuracy: 0.8052, Test Accuracy: 0.7415
# Epoch [7/20], Train Accuracy: 0.8076, Test Accuracy: 0.7500
# Epoch [8/20], Train Accuracy: 0.8242, Test Accuracy: 0.7542
# Epoch [9/20], Train Accuracy: 0.8444, Test Accuracy: 0.7500
# Epoch [10/20], Train Accuracy: 0.8504, Test Accuracy: 0.7331
# Epoch [11/20], Train Accuracy: 0.8420, Test Accuracy: 0.7585
# Epoch [12/20], Train Accuracy: 0.8670, Test Accuracy: 0.7415
# Epoch [13/20], Train Accuracy: 0.8610, Test Accuracy: 0.7669
# Epoch [14/20], Train Accuracy: 0.8800, Test Accuracy: 0.7542
# Epoch [15/20], Train Accuracy: 0.8824, Test Accuracy: 0.7754
# Epoch [16/20], Train Accuracy: 0.8812, Test Accuracy: 0.7712
# Epoch [17/20], Train Accuracy: 0.8931, Test Accuracy: 0.7839
# Epoch [18/20], Train Accuracy: 0.8729, Test Accuracy: 0.7839
# Epoch [19/20], Train Accuracy: 0.8943, Test Accuracy: 0.7839
# Epoch [20/20], Train Accuracy: 0.8967, Test Accuracy: 0.7797
# Epoch [1/20], Train Accuracy: 0.7765, Test Accuracy: 0.8447
# Epoch [2/20], Train Accuracy: 0.7765, Test Accuracy: 0.8447
# Epoch [3/20], Train Accuracy: 0.7765, Test Accuracy: 0.8447
# Epoch [4/20], Train Accuracy: 0.7765, Test Accuracy: 0.8447
# Epoch [5/20], Train Accuracy: 0.7776, Test Accuracy: 0.8128
# Epoch [6/20], Train Accuracy: 0.7974, Test Accuracy: 0.7626
# Epoch [7/20], Train Accuracy: 0.7986, Test Accuracy: 0.7626
# Epoch [8/20], Train Accuracy: 0.8161, Test Accuracy: 0.7534
# Epoch [9/20], Train Accuracy: 0.8137, Test Accuracy: 0.7489
# Epoch [10/20], Train Accuracy: 0.8149, Test Accuracy: 0.7534
# Epoch [11/20], Train Accuracy: 0.8300, Test Accuracy: 0.7169
# Epoch [12/20], Train Accuracy: 0.8556, Test Accuracy: 0.7078
# Epoch [13/20], Train Accuracy: 0.8696, Test Accuracy: 0.6438
# Epoch [14/20], Train Accuracy: 0.8754, Test Accuracy: 0.6712
# Epoch [15/20], Train Accuracy: 0.8591, Test Accuracy: 0.7169
# Epoch [16/20], Train Accuracy: 0.8859, Test Accuracy: 0.6712
# Epoch [17/20], Train Accuracy: 0.8871, Test Accuracy: 0.6849
# Epoch [18/20], Train Accuracy: 0.9092, Test Accuracy: 0.6119
# Epoch [19/20], Train Accuracy: 0.9127, Test Accuracy: 0.6712
# Epoch [20/20], Train Accuracy: 0.9057, Test Accuracy: 0.6712
# Epoch [1/20], Train Accuracy: 0.8013, Test Accuracy: 0.7604
# Epoch [2/20], Train Accuracy: 0.8013, Test Accuracy: 0.7604
# Epoch [3/20], Train Accuracy: 0.8013, Test Accuracy: 0.7604
# Epoch [4/20], Train Accuracy: 0.8013, Test Accuracy: 0.7604
# Epoch [5/20], Train Accuracy: 0.8038, Test Accuracy: 0.7396
# Epoch [6/20], Train Accuracy: 0.8190, Test Accuracy: 0.6736
# Epoch [7/20], Train Accuracy: 0.8266, Test Accuracy: 0.6424
# Epoch [8/20], Train Accuracy: 0.8329, Test Accuracy: 0.6528
# Epoch [9/20], Train Accuracy: 0.8367, Test Accuracy: 0.6528
# Epoch [10/20], Train Accuracy: 0.8456, Test Accuracy: 0.6354
# Epoch [11/20], Train Accuracy: 0.8582, Test Accuracy: 0.6215
# Epoch [12/20], Train Accuracy: 0.8734, Test Accuracy: 0.6354
# Epoch [13/20], Train Accuracy: 0.8658, Test Accuracy: 0.6250
# Epoch [14/20], Train Accuracy: 0.8696, Test Accuracy: 0.6250
# Epoch [15/20], Train Accuracy: 0.8810, Test Accuracy: 0.6215
# Epoch [16/20], Train Accuracy: 0.9025, Test Accuracy: 0.6076
# Epoch [17/20], Train Accuracy: 0.9025, Test Accuracy: 0.6215
# Epoch [18/20], Train Accuracy: 0.9038, Test Accuracy: 0.6250
# Epoch [19/20], Train Accuracy: 0.9291, Test Accuracy: 0.5972
# Epoch [20/20], Train Accuracy: 0.9253, Test Accuracy: 0.6146
# Epoch [1/20], Train Accuracy: 0.7701, Test Accuracy: 0.8513
# Epoch [2/20], Train Accuracy: 0.7701, Test Accuracy: 0.8513
# Epoch [3/20], Train Accuracy: 0.7738, Test Accuracy: 0.8513
# Epoch [4/20], Train Accuracy: 0.7899, Test Accuracy: 0.8513
# Epoch [5/20], Train Accuracy: 0.7960, Test Accuracy: 0.8513
# Epoch [6/20], Train Accuracy: 0.8096, Test Accuracy: 0.8327
# Epoch [7/20], Train Accuracy: 0.8208, Test Accuracy: 0.8067
# Epoch [8/20], Train Accuracy: 0.8418, Test Accuracy: 0.7063
# Epoch [9/20], Train Accuracy: 0.8492, Test Accuracy: 0.7249
# Epoch [10/20], Train Accuracy: 0.8554, Test Accuracy: 0.7509
# Epoch [11/20], Train Accuracy: 0.8665, Test Accuracy: 0.7509
# Epoch [12/20], Train Accuracy: 0.8826, Test Accuracy: 0.6840
# Epoch [13/20], Train Accuracy: 0.8813, Test Accuracy: 0.7993
# Epoch [14/20], Train Accuracy: 0.8949, Test Accuracy: 0.7918
# Epoch [15/20], Train Accuracy: 0.8949, Test Accuracy: 0.8030
# Epoch [16/20], Train Accuracy: 0.9011, Test Accuracy: 0.8067
# Epoch [17/20], Train Accuracy: 0.9234, Test Accuracy: 0.7323
# Epoch [18/20], Train Accuracy: 0.9258, Test Accuracy: 0.6691
# Epoch [19/20], Train Accuracy: 0.9431, Test Accuracy: 0.7361
# Epoch [20/20], Train Accuracy: 0.9431, Test Accuracy: 0.7546
# Epoch [1/20], Train Accuracy: 0.7774, Test Accuracy: 0.8409
# Epoch [2/20], Train Accuracy: 0.7774, Test Accuracy: 0.8409
# Epoch [3/20], Train Accuracy: 0.7774, Test Accuracy: 0.8409
# Epoch [4/20], Train Accuracy: 0.7774, Test Accuracy: 0.8409
# Epoch [5/20], Train Accuracy: 0.7774, Test Accuracy: 0.8409
# Epoch [6/20], Train Accuracy: 0.8112, Test Accuracy: 0.7409
# Epoch [7/20], Train Accuracy: 0.8159, Test Accuracy: 0.7273
# Epoch [8/20], Train Accuracy: 0.8380, Test Accuracy: 0.7545
# Epoch [9/20], Train Accuracy: 0.8485, Test Accuracy: 0.7318
# Epoch [10/20], Train Accuracy: 0.8601, Test Accuracy: 0.7591
# Epoch [11/20], Train Accuracy: 0.8671, Test Accuracy: 0.7045
# Epoch [12/20], Train Accuracy: 0.8660, Test Accuracy: 0.7364
# Epoch [13/20], Train Accuracy: 0.8765, Test Accuracy: 0.6955
# Epoch [14/20], Train Accuracy: 0.8788, Test Accuracy: 0.7636
# Epoch [15/20], Train Accuracy: 0.8939, Test Accuracy: 0.7364
# Epoch [16/20], Train Accuracy: 0.8893, Test Accuracy: 0.7364
# Epoch [17/20], Train Accuracy: 0.8916, Test Accuracy: 0.7409
# Epoch [18/20], Train Accuracy: 0.9044, Test Accuracy: 0.7500
# Epoch [19/20], Train Accuracy: 0.9079, Test Accuracy: 0.7500
# Epoch [20/20], Train Accuracy: 0.9277, Test Accuracy: 0.7364
# Epoch [1/20], Train Accuracy: 0.7976, Test Accuracy: 0.7468
# Epoch [2/20], Train Accuracy: 0.7976, Test Accuracy: 0.7468
# Epoch [3/20], Train Accuracy: 0.7976, Test Accuracy: 0.7468
# Epoch [4/20], Train Accuracy: 0.7976, Test Accuracy: 0.7468
# Epoch [5/20], Train Accuracy: 0.7976, Test Accuracy: 0.7468
# Epoch [6/20], Train Accuracy: 0.7976, Test Accuracy: 0.7468
# Epoch [7/20], Train Accuracy: 0.8019, Test Accuracy: 0.7468
# Epoch [8/20], Train Accuracy: 0.8117, Test Accuracy: 0.7468
# Epoch [9/20], Train Accuracy: 0.8247, Test Accuracy: 0.7468
# Epoch [10/20], Train Accuracy: 0.8431, Test Accuracy: 0.7468
# Epoch [11/20], Train Accuracy: 0.8323, Test Accuracy: 0.7468
# Epoch [12/20], Train Accuracy: 0.8550, Test Accuracy: 0.7468
# Epoch [13/20], Train Accuracy: 0.8626, Test Accuracy: 0.7468
# Epoch [14/20], Train Accuracy: 0.8701, Test Accuracy: 0.7468
# Epoch [15/20], Train Accuracy: 0.8745, Test Accuracy: 0.7468
# Epoch [16/20], Train Accuracy: 0.8983, Test Accuracy: 0.7532
# Epoch [17/20], Train Accuracy: 0.9037, Test Accuracy: 0.7468
# Epoch [18/20], Train Accuracy: 0.9102, Test Accuracy: 0.7597
# Epoch [19/20], Train Accuracy: 0.9145, Test Accuracy: 0.7532
# Epoch [20/20], Train Accuracy: 0.9188, Test Accuracy: 0.7532
# Epoch [1/20], Train Accuracy: 0.8034, Test Accuracy: 0.7075
# Epoch [2/20], Train Accuracy: 0.8034, Test Accuracy: 0.7075
# Epoch [3/20], Train Accuracy: 0.8034, Test Accuracy: 0.7075
# Epoch [4/20], Train Accuracy: 0.8034, Test Accuracy: 0.7075
# Epoch [5/20], Train Accuracy: 0.8034, Test Accuracy: 0.7075
# Epoch [6/20], Train Accuracy: 0.8056, Test Accuracy: 0.7075
# Epoch [7/20], Train Accuracy: 0.8110, Test Accuracy: 0.7075
# Epoch [8/20], Train Accuracy: 0.8142, Test Accuracy: 0.7075
# Epoch [9/20], Train Accuracy: 0.8195, Test Accuracy: 0.7075
# Epoch [10/20], Train Accuracy: 0.8378, Test Accuracy: 0.7007
# Epoch [11/20], Train Accuracy: 0.8335, Test Accuracy: 0.7075
# Epoch [12/20], Train Accuracy: 0.8443, Test Accuracy: 0.7075
# Epoch [13/20], Train Accuracy: 0.8765, Test Accuracy: 0.6803
# Epoch [14/20], Train Accuracy: 0.8980, Test Accuracy: 0.6735
# Epoch [15/20], Train Accuracy: 0.9033, Test Accuracy: 0.6939
# Epoch [16/20], Train Accuracy: 0.8883, Test Accuracy: 0.7143
# Epoch [17/20], Train Accuracy: 0.9205, Test Accuracy: 0.6735
# Epoch [18/20], Train Accuracy: 0.9259, Test Accuracy: 0.7279
# Epoch [19/20], Train Accuracy: 0.9291, Test Accuracy: 0.7075
# Epoch [20/20], Train Accuracy: 0.9270, Test Accuracy: 0.7075
# MLP
# ROC AUC:  0.5372
# PR AUC:  0.8359
