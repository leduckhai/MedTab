# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install catboost
# !pip install lightgbm
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.5)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.3.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.11.4)

# %%
import pandas as pd
from dateutil import parser
from collections import defaultdict
from copy import deepcopy
import random
import statistics
import math
import numpy as np
import ast
import statistics
import matplotlib.pyplot as plt

from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, roc_curve, auc, precision_recall_curve

from sklearn.ensemble import GradientBoostingClassifier

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

from catboost import CatBoostClassifier

import lightgbm as lgb

from sklearn.preprocessing import LabelEncoder

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/LDF
# Out:
# /content/drive/.shortcut-targets-by-id/10cLNvGYZ8jCz5UzVVMmUw1kONRPJ_red/LDF

# %% [markdown]
# # Help functions

# %% [markdown]
# ## Data imputation

# %%
def data_imputation(X_train, X_test, imputation_method='mean'):
  # This function imputes the data based on the train set
  # and apply the imputed values to the test set

  if imputation_method == 'mean':

    # Calculate mean per column
    n = len(X_train[0])
    memo = [np.asfarray([0 for i in range(n)]), np.asfarray([0.0 for i in range(n)])] # [Count, Sum]

    for i in range(len(X_train)):
      for j in range(len(X_train[i])):
        if np.isnan(X_train[i][j]) != True:
          memo[0][j] += 1
          memo[1][j] += X_train[i][j]

    for j in range(n):
      memo[1][j] = memo[1][j]/memo[0][j] # ==> [Count, Mean]

    # Data imputation
    for i in range(len(X_train)):
      for j in range(len(X_train[i])):
        if np.isnan(X_train[i][j]) == True:
          X_train[i][j] = memo[1][j]

    for i in range(len(X_test)):
      for j in range(len(X_test[i])):
        if np.isnan(X_test[i][j]) == True:
          X_test[i][j] = memo[1][j]

  return X_train, X_test

# %% [markdown]
# ## In-the-loop normalization

# %%
def data_normalization(X_train, X_test):
  # This function normalizes the data based on the train set
  # and apply the normalized values to the test set

  # Convert to float to get more precise results (yet empirically proved)
  X_train = np.asfarray(X_train)
  X_test = np.asfarray(X_test)

  # Memoization: [Minimums, Maximums]
  memo = deepcopy([X_train[0], X_train[0]])
  for row in X_train:
    for i in range(len(row)):
      if row[i] < memo[0][i]:
        memo[0][i] = row[i]
      if row[i] > memo[1][i]:
        memo[1][i] = row[i]

  # Normalization on train set
  for r in range(len(X_train)):
    for c in range(len(X_train[0])):
      if memo[1][c]-memo[0][c] == 0:
        X_train[r][c] = (X_train[r][c] - memo[0][c])/(1e-20)
      else:
        X_train[r][c] = (X_train[r][c] - memo[0][c])/(memo[1][c]-memo[0][c])

  # Normalization on test set
  for r in range(len(X_test)):
    for c in range(len(X_test[0])):
      if memo[1][c]-memo[0][c] == 0:
        X_test[r][c] = (X_test[r][c] - memo[0][c])/(1e-20)
      else:
        X_test[r][c] = (X_test[r][c] - memo[0][c])/(memo[1][c]-memo[0][c])
      # Rescale
      if X_test[r][c] > 1.0:
        X_test[r][c] = 1.0
      elif X_test[r][c] < 0.0:
        X_test[r][c] = 0.0

  return X_train, X_test

# %% [markdown]
# ## Leave one person out

# %%
def leave_one_person_out(patient_ids):
  loo = dict()
  for patient_id in set(patient_ids):
    loo[patient_id] = None

  for patient_id in loo:
    train_indices, test_indices = [], []

    for i in range(len(patient_ids)):
      if patient_ids[i] == patient_id:
        test_indices.append(i)
      else:
        train_indices.append(i)

    loo[patient_id] = [train_indices, test_indices]

  return loo

# %% [markdown]
# ## K-fold

# %%
def k_fold(patient_ids, number_of_folds = 5):
  patient_id_dict = dict()
  for patient_id in set(patient_ids):
    patient_id_dict[patient_id] = []

  for i in range(len(patient_ids)):
    patient_id = patient_ids[i]
    patient_id_dict[patient_id].append(i)

  kfold_dict = dict()
  i, k = 0, len(patient_id_dict.keys())//number_of_folds
  queue = list(patient_id_dict.keys())

  while queue:
    random.shuffle(queue)
    patient_id_test = [j for j in queue[0:k] ]
    patient_id_train = [j for j in set(patient_id_dict.keys())-set(patient_id_test) ]

    train_indices, test_indices = [], []
    for patient_id in patient_id_train:
      train_indices += patient_id_dict[patient_id]
    for patient_id in patient_id_test:
      test_indices += patient_id_dict[patient_id]
    kfold_dict[i] = [train_indices, test_indices]

    queue = queue[k:]
    i += 1

  return kfold_dict

# %% [markdown]
# ## AUC plot

# %%
def AUC_plot(y, preds):
  figure, axis = plt.subplots(1, 2)

  # ROC AUC
  fpr, tpr, thresholds = roc_curve(y, preds, #pos_label=1
                                   )
  roc_auc = round(auc(fpr, tpr), 4)
  print('ROC AUC: ', roc_auc)
  #print('FPR: ', fpr, 'TPR: ', tpr) # For debugging
  axis[0].plot(fpr, tpr)
  axis[0].set_title('ROC AUC')
  axis[0].set_xlabel('FPR')
  axis[0].set_ylabel('TPR')

  # PR AUC
  precision, recall, thresholds = precision_recall_curve(y, preds, pos_label=1)
  pr_auc = round(auc(recall,precision), 4)
  print('PR AUC: ', pr_auc)
  #print('Recall: ', recall, 'Precision: ', precision) # For debugging
  axis[1].plot(recall, precision)
  axis[1].set_title('ROC PR')
  axis[1].set_xlabel('Recall')
  axis[1].yaxis.set_label_position("right")
  axis[1].set_ylabel('Precision')

  plt.show()

# %% [markdown]
# ## One-hot encoding

# %%
def onehot_encoding(df):
  # Encode categorical variables and store the mapping
  label_encoder = LabelEncoder()
  encoded_values = {}

  for column in df.columns:
    if df[column].dtype == 'O' and column != '1. Volunteer full name':
      df[column] = label_encoder.fit_transform(df[column])
      encoded_values[column] = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

      print(f'Feature: {column} \n', encoded_values[f'{column}'])

  return encoded_values, df

# %% [markdown]
# ## MLP Binary

# %%
# Define the MLP architecture for binary classification
class MLPBinary(nn.Module):
  def __init__(self, input_size, hidden_size, dropout_prob):
    super(MLPBinary, self).__init__()
    self.layer_norm = nn.LayerNorm(input_size)
    self.fc1 = nn.Linear(input_size, hidden_size)
    self.relu = nn.ReLU()
    self.dropout = nn.Dropout(dropout_prob)
    self.fc2 = nn.Linear(hidden_size, hidden_size)
    self.fc3 = nn.Linear(hidden_size, 1)
    self.sigmoid = nn.Sigmoid()

  def forward(self, x):
    out = self.layer_norm(x)
    out = self.fc1(out)
    out = self.relu(out)
    out = self.dropout(out)
    out = self.fc2(out)
    out = self.relu(out)
    out = self.dropout(out)
    out = self.fc3(out)
    out = self.sigmoid(out)
    return out


def MLP_training(X_train, X_test, y_train, y_test):
  # Data imputation
  X_train, X_test = data_imputation(X_train, X_test,
                                    imputation_method='mean')

  # Data normalization
  X_train, X_test = data_normalization(X_train, X_test)

  # Convert NumPy arrays to PyTorch tensors
  y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
  y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

  # Convert data to PyTorch tensors
  X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
  X_test_tensor = torch.tensor(X_test, dtype=torch.float32)

  # Create DataLoader
  train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

  # Initialize model, loss function, and optimizer
  model = MLPBinary(input_size, hidden_size, dropout_prob)
  criterion = nn.BCELoss()
  optimizer = optim.Adam(model.parameters(), lr=learning_rate)

  # Define variables to track the best model and its accuracy
  best_accuracy = 0
  best_model = None

  # Training the model
  for epoch in range(num_epochs):
    # Train
    model.train()
    for i, (inputs, labels) in enumerate(train_loader):
      optimizer.zero_grad()
      outputs = model(inputs)
      loss = criterion(outputs, labels.unsqueeze(1))
      loss.backward()
      optimizer.step()

      # Evaluate on train set
      train_outputs = model(X_train_tensor)
      train_predicted = (train_outputs > 0.5).squeeze().int()
      train_accuracy = (train_predicted == y_train_tensor.int()).sum().item() / len(y_train_tensor)

    # Evaluate on test set
    with torch.no_grad():
      model.eval()
      test_outputs = model(X_test_tensor)
      test_predicted = (test_outputs > 0.5).squeeze().int()
      test_accuracy = (test_predicted == y_test_tensor.int()).sum().item() / len(y_test_tensor)

    # Print accuracy for each epoch
    print('Epoch [{}/{}], Train Accuracy: {:.4f}, Test Accuracy: {:.4f}'.format(epoch+1, num_epochs, train_accuracy, test_accuracy))

    # Save the best model
    if test_accuracy > best_accuracy:
      best_accuracy = test_accuracy
      best_model = model.state_dict()

  # Save the best model
  torch.save(best_model, 'best_model.pth')


def MLP_inference(X_test):
  X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
  model = MLPBinary(input_size, hidden_size, dropout_prob)
  model.load_state_dict(torch.load('best_model.pth'))
  model.eval()

  with torch.no_grad():
    y_test_predicted = model(X_test_tensor).squeeze()
    y_test_predicted = y_test_predicted.numpy()

  return y_test_predicted

# %% [markdown]
# # Top 10 important features - Binary classification

# %%
df_rawdata = pd.read_excel('Data/20-05-2024_TextNorm.xlsx')
print(df_rawdata.dtypes)
df_rawdata
# Out:
# Type of data                                 object
# Patient_ID                                   object
# Kv100                                       float64
# M                                           float64
# δ                                           float64
# T                                           float64
# A365                                        float64
# A460                                        float64
# Anadn                                       float64
# POM                                         float64
# Ae                                          float64
# An                                          float64
# Am                                          float64
# Ar                                          float64
# Ac                                          float64
# F_Ae                                        float64
# F_An                                        float64
# F_Am                                        float64
# F_Ar                                        float64
# F_Ac                                        float64
# Ethnicity                                    object
# Left or Right                                object
# Sleep                                        object
# Gender                                       object
# Race                                         object
# Type of skins                                 int64
# Age                                           int64
# Weight                                      float64
# Height                                        int64
# BMI_index                                   float64
# Smoking                                      object
# Number of cigarettes per week if smoked:    float64
# Disease                                      object
# Blood Pressure                               object
# Level of BP                                   int64
# Heart Rate                                  float64
# DASS_21                                      object
# Stress                                        int64
# Anxiety                                       int64
# Depression                                    int64
# Hypertension                                  int64
# Non-wellbeing                                 int64
# dtype: object
#      Type of data        Patient_ID  Kv100      M     δ      T   A365  A460  \
# 0        Original  Minh Ngoc Nguyen  12.90  22.50  2.90  32.01  114.0  62.0
# 1        Original  Minh Ngoc Nguyen  22.28  22.55  5.02  32.14  122.0  42.0
# 2          Filter  Minh Ngoc Nguyen  11.10  22.85  2.54  32.04  114.0  62.0
# 3          Filter  Minh Ngoc Nguyen  20.78  23.01  4.78  23.01  122.0  41.0
# 4        Original         Hong Pham  20.76   4.39  0.91  24.44  132.0  93.0
# ...           ...               ...    ...    ...   ...    ...    ...   ...
# 1073     Original     Giang Thi Sot  28.89  16.62  4.80  30.75   78.0  97.0
# 1074     Original   Nguyen Ba Tuyen  27.52  18.78  5.17  36.86   92.0  71.0
# 1075     Original   Nguyen Ba Tuyen  10.34  23.96  2.48  35.89   82.0  31.0
# 1076     Original     Mac Van Thang  26.75  24.51  6.56  35.07   53.0  40.0
# 1077     Original     Mac Van Thang   8.55  27.94  2.39  34.01   46.0  26.0
#
#       Anadn    POM  ...         Disease  Blood Pressure  Level of BP  \
# 0      0.54   5.68  ...        Migraine          Normal            0
# 1      0.34  10.38  ...        Migraine          Normal            0
# 2      0.54   7.54  ...        Migraine          Normal            0
# 3      0.33  11.31  ...        Migraine          Normal            0
# 4      0.70   0.91  ...        Migraine          Normal            0
# ...     ...    ...  ...             ...             ...          ...
# 1073   1.24   3.02  ...  Diabetes, MACE        Elevated            1
# 1074   0.77   3.77  ...  Diabetes, MACE        Elevated            1
# 1075   0.37  13.40  ...  Diabetes, MACE        Elevated            1
# 1076   0.77   7.49  ...            MACE        Elevated            1
# 1077   0.58  10.98  ...            MACE        Elevated            1
#
#       Heart Rate  DASS_21  Stress  Anxiety  Depression  Hypertension  \
# 0           95.0   NORMAL       0        0           0             0
# 1           95.0   NORMAL       0        0           0             0
# 2           95.0   NORMAL       0        0           0             0
# 3           95.0   NORMAL       0        0           0             0
# 4           70.0   NORMAL       0        0           0             0
# ...          ...      ...     ...      ...         ...           ...
# 1073        70.0   NORMAL       0        0           0             1
# 1074        70.0   NORMAL       0        0           0             1
# 1075        70.0   NORMAL       0        0           0             1
# 1076        70.0   NORMAL       0        0           0             1
# 1077        70.0   NORMAL       0        0           0             1
#
#       Non-wellbeing
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 1073              0
# 1074              0
# 1075              0
# 1076              0
# 1077              0
#
# [1078 rows x 42 columns]

# %%
# Convert Multiclass to Binary
for i in range(len(df_rawdata['DASS_21'])):
  if df_rawdata['DASS_21'][i] == 'NORMAL':
    pass
  else:
    df_rawdata['DASS_21'][i] = 'ABNORMAL'

# df_rawdata['DASS_21'].unique() # For debugging

# One-hot encoding
encoded_values, df_rawdata = onehot_encoding(df_rawdata)
# Out:
# Feature: Type of data
#  {'Filter': 0, 'Fragment 1': 1, 'Fragment 2': 2, 'Fragment 3': 3, 'Original': 4, 'fragment1': 5, 'fragment2': 6}
# Feature: Patient_ID
#  {'A Amalraja': 0, 'Abdul Raheem': 1, 'Aisha Bibi': 2, 'Aleksandr Koviarov': 3, 'Alice': 4, 'Anh Tai': 5, 'Anh Toan': 6, 'Arooj Arooj': 7, 'Badmos': 8, 'Barandewte Rose': 9, 'Bui Thi Hue': 10, 'Bui Thi Phú': 11, 'Bùi Kim Dung': 12, 'Bùi Thuý Thi': 13, 'Bùi Xuân Khoa': 14, 'Caroline': 15, 'Chi Hao': 16, 'Cong Huan Hoang': 17, 'Dam Thi Thoa': 18, 'Daniel': 19, 'Dao Huy Co': 20, 'Dao Van Tuy': 21, 'Diana Galiakhmetova': 22, 'Dini': 23, 'Do Van Khai': 24, 'Doan Thi Chu': 25, 'Doan Xuan Dinh': 26, 'Duc Tran van': 27, 'Duong Thu Trang': 28, 'E Lieu': 29, 'E Nam': 30, 'E Phi': 31, 'E Thuy': 32, 'E Trung': 33, 'Em Son': 34, 'Emad Tandis': 35, 'Fanchesco': 36, 'Gauthami': 37, 'Geraldo Gomes De Luna Junior': 38, 'Giang Thi Sot': 39, 'Hani Kbashi': 40, 'Hien dang': 41, 'Hoang Thi Mien': 42, 'Hoang Thi Quynh Ngan': 43, 'Hoang Thi Sam': 44, 'Hoang Vu Manh': 45, 'Holland': 46, 'Hong Pham': 47, 'Huyen Vung Tau': 48, 'Huynh Thi Trung Hau': 49, 'Imtiaz Sheik': 50, 'Imtiaz iqbal': 51, 'Indian Man': 52, 'Kanye Tunkara': 53, 'Karen': 54, 'Karina': 55, 'Kien': 56, 'Kirill Tokmakov': 57, 'Kirthan Niranjan': 58, 'La Ngoc Vien': 59, 'Lam Hoang': 60, 'Le Duy Binh': 61, 'Le Thi Hang': 62, 'Le Thi Hau': 63, 'Lukman Kamarudin': 64, 'Luu Thanh Tam': 65, 'Lê Thị Lập': 66, 'Lê Thị Mai Y Nguyên': 67, 'Lê Thị Thu Bình': 68, 'Lê Trọng Mạnh': 69, 'Mac Thi Sim': 70, 'Mac Van Thang': 71, 'Maria': 72, 'Mark Avery': 73, 'Meisam Shiri': 74, 'Minh Ngoc Nguyen': 75, 'Minji': 76, 'Mohammed Patel': 77, 'Muhammad Azmat': 78, 'Negar Shaabani Shishavan': 79, 'Nelson Castro Salgado': 80, 'Ngo sy phuong': 81, 'Nguyen Anh Tuan': 82, 'Nguyen Anh Tuan 2': 83, 'Nguyen Ba Tuyen': 84, 'Nguyen Duc': 85, 'Nguyen Duc Vy': 86, 'Nguyen Ngoc Lan': 87, 'Nguyen Phuc hoi': 88, 'Nguyen Tan An': 89, 'Nguyen Thi Binh': 90, 'Nguyen Thi Bo': 91, 'Nguyen Thi Diu': 92, 'Nguyen Thi Hao': 93, 'Nguyen Thi Hong Ngan': 94, 'Nguyen Thi Hong Van': 95, 'Nguyen Thi Huyen': 96, 'Nguyen Thi Hương': 97, 'Nguyen Thi Lien': 98, 'Nguyen Thi Luyen': 99, 'Nguyen Thi Mai': 100, 'Nguyen Thi Mai Anh': 101, 'Nguyen Thi Ngan': 102, 'Nguyen Thi Ngoc Tram': 103, 'Nguyen Thi Thi': 104, 'Nguyen Thi Vung': 105, 'Nguyen Van Hoa': 106, 'Nguyen Van Lam': 107, 'Nguyen Xuan Dien': 108, 'Nguyen duc dung': 109, 'Nguyen hoang long': 110, 'Nguyen thi thuy': 111, 'Nguyen van Thai': 112, 'Nguyen vu cam giang': 113, 'Nguyễn Thị Lan Phương': 114, 'Nguyễn Thị Thanh Nhài': 115, 'Nguyễn Thị Thúy Duyên': 116, 'Nguyễn Văn Lợi': 117, 'Nguyễn Xuân Hùng': 118, 'Nguyễn đức thắng': 119, 'Nhan': 120, 'Nhan dau': 121, 'Nida': 122, 'Nur Alia Sheh Omar': 123, 'Nxhoang': 124, 'Patrick Jones': 125, 'Pedro': 126, 'Pham Ba Toa': 127, 'Pham Cong Duong': 128, 'Pham Hung Cuong': 129, 'Pham Ngoc Am': 130, 'Pham Van Thanh': 131, 'Pham van tap': 132, 'Phan Thi Thuy Nga': 133, 'Phung Thi Linh': 134, 'Rghavan': 135, 'Ricardo Jose': 136, 'Sofia': 137, 'Sofia Koviarova': 138, 'Surayyah Amatul Aziz': 139, 'Syed Atif Iqrar': 140, 'Tetyana Gordienko': 141, 'Thanh Nguyen': 142, 'Thanh tran': 143, 'The': 144, 'Tran Duc': 145, 'Tran Phuong Linh ': 146, 'Tran Quoc Ha': 147, 'Tran Van No': 148, 'Tran Van Tho': 149, 'Tran Van Vy': 150, 'Tran thi Hai Duyen': 151, 'Trang Nhung': 152, 'Trinh Dinh Luan': 153, 'Truong My linh': 154, 'Trương Hải Nam': 155, 'Tu thi Minh Phuong': 156, 'Tuan Dau': 157, 'Victoria': 158, 'Vo Thi Thu Hien': 159, 'Vo van tuan': 160, 'Vu Le Hieu': 161, 'Vu Ngoc Liem': 162, 'Vu Thi Ha': 163, 'Vu thi vuong': 164, 'Vuong Van Thuc': 165, 'Vy': 166, 'Vy Thi My': 167, 'Waqar ahmad': 168, 'Yasmin Butt': 169, 'Yuekit ma': 170, 'Zifie Wang': 171, 'anh Tao': 172, 'do thi ngoc anh': 173, 'doan thi hong': 174, 'jaurn': 175, 'le thu huyen': 176, 'nguyen Hoang Minh Nhut': 177, 'nguyen thi cam': 178, 'nguyen thi kien': 179, 'nguyen thi ngoan': 180, 'nguyen thi nhung': 181, 'nguyen văn hợp': 182, 'nguyễn thị giang': 183, 'nguyễn thị lải': 184, 'pham thi nham': 185, 'phan thi mười': 186, 'phạm thị vân anh': 187, 'tang thi yen': 188, 'tran thi duyen': 189, 'tran thi hoa ...
# Feature: Ethnicity
#  {'Bahrain': 0, 'Brazil': 1, 'British': 2, 'China': 3, 'India': 4, 'Indonesia': 5, 'Iran': 6, 'Iraq': 7, 'Italy': 8, 'Jamaica': 9, 'Kenya': 10, 'Kjastan': 11, 'Malaysia': 12, 'Mexico': 13, 'Nigeria': 14, 'Pakistan': 15, 'Russia': 16, 'Spain': 17, 'Sweden': 18, 'Vietnam': 19}
# Feature: Left or Right
#  {'Left': 0, 'Right': 1}
# Feature: Sleep
#  {'No': 0, 'Yes': 1}
# Feature: Gender
#  {'Female': 0, 'Male': 1}
# Feature: Race
#  {'Asian or Asian British': 0, 'Black, African, Caribbean or Black British': 1, 'White': 2}
# Feature: Smoking
#  {'Cigarettes, pipe tobacco...': 0, 'Do not smoke': 1, 'ex smoke': 2}
# Feature: Disease
#  {'Anemia': 0, 'Diabetes': 1, 'Diabetes Hypertension': 2, 'Diabetes, MACE': 3, 'Diabetes, degenerative spine': 4, 'Diabetes, hypertension,diabetic complications (MACE)': 5, 'Heart Failure, OAP, Afb': 6, 'Heart Failure, Pneumonia, STEMI': 7, 'Heart Failure, STEMI': 8, 'Heart Failure, STEMI, HYPERTENSION, Diabetes 2': 9, 'Heart Failure, STEMI,BAV3': 10, 'Heart Failure, cononary D with stent placed': 11, 'Heart Failure,STEMI,HYPERTENSION': 12, 'Hepatitis B': 13, 'Hypertension': 14, 'Hypertension Hepatitis B': 15, 'Hypertension Migraine': 16, 'Hypertension Migraine Hepatitis B': 17, 'MACE': 18, 'Migraine': 19, 'No': 20, 'Post Brian Sugery': 21, 'Post sroke': 22, 'Pregnant': 23, 'Thalassemia': 24}
# Feature: Blood Pressure
#  {'Elevated': 0, 'High blood': 1, 'Hypertensive crisis': 2, 'Normal': 3}
# Feature: DASS_21
#  {'ABNORMAL': 0, 'NORMAL': 1}
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# ...
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'
# <ipython-input-27-af3626d57ece>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rawdata['DASS_21'][i] = 'ABNORMAL'

# %%
input = ['BMI_index', 'Heart Rate', 'Age', 'Type of skins', 'Weight',
         'T', 'Height', 'A460', 'Anadn', 'M'
         ]
output = [#'Ethnicity', 'Left or Right', 'Sleep', 'Gender', 'Race',
          #'Smoking',
          #'Disease',
          'DASS_21',
          #'Stress', 'Anxiety', 'Depression', 'Hypertension', 'Non-wellbeing'
          ]

X_rawdata = df_rawdata[input].values
y_dass21 = df_rawdata['DASS_21'].values

patient_ids = list(df_rawdata['Patient_ID'])

# %% [markdown]
# ## Leave-one-patient-out

# %% [markdown]
# ### Gradient Boosting

# %%
# Gradient Boosting
d_preds = {'labels': [], 'preds': []}

loo = leave_one_person_out(patient_ids)

for patient_id in loo:
  # Leave one out
  train_indices = np.array(loo[patient_id][0])
  test_indices = np.array(loo[patient_id][1])

  X_rawdata_train = X_rawdata[train_indices]
  X_rawdata_test = X_rawdata[test_indices]
  y_dass21_train = y_dass21[train_indices]
  y_dass21_test = y_dass21[test_indices]

  # Data imputation
  X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                    imputation_method='mean')

  # Classification
  clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
                                   max_depth=1, random_state=0).fit(X_rawdata_train, y_dass21_train)
  d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
  d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('Gradient Boosting')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Gradient Boosting
# ROC AUC:  0.6699
# PR AUC:  0.8689

# %% [markdown]
# ### Catboost

# %%
# Catboost
d_preds = {'labels': [], 'preds': []}

loo = leave_one_person_out(patient_ids)

for patient_id in loo:
  # Leave one out
  train_indices = np.array(loo[patient_id][0])
  test_indices = np.array(loo[patient_id][1])

  X_rawdata_train = X_rawdata[train_indices]
  X_rawdata_test = X_rawdata[test_indices]
  y_dass21_train = y_dass21[train_indices]
  y_dass21_test = y_dass21[test_indices]

  # Data imputation
  X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                    imputation_method='mean')

  # Classification
  clf = CatBoostClassifier(iterations=2, learning_rate=1, depth=2)
  clf.fit(X_rawdata_train, y_dass21_train, verbose=False)
  d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
  d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('Catboost')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Catboost
# ROC AUC:  0.5788
# PR AUC:  0.8213

# %% [markdown]
# ### LightGBM

# %%
# LightGBM
d_preds = {'labels': [], 'preds': []}

loo = leave_one_person_out(patient_ids)

for patient_id in loo:
  # Leave one out
  train_indices = np.array(loo[patient_id][0])
  test_indices = np.array(loo[patient_id][1])

  X_rawdata_train = X_rawdata[train_indices]
  X_rawdata_test = X_rawdata[test_indices]
  y_dass21_train = y_dass21[train_indices]
  y_dass21_test = y_dass21[test_indices]

  # Data imputation
  X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                    imputation_method='mean')

  # Classification
  train_data = lgb.Dataset(X_rawdata_train, label=y_dass21_train)
  test_data = lgb.Dataset(X_rawdata_test, label=y_dass21_test, reference=train_data)
  params = {
      'objective': 'binary',
      'metric': 'binary_logloss',
      'num_leaves': 31,
      #'learning_rate': 0.05,
      'learning_rate': 0.1,
      'n_estimators': 100,
      'verbose': -1
  }
  bst = lgb.train(params, train_data, valid_sets=[train_data, test_data])
  y_dass21_test_preds = bst.predict(X_rawdata_test, num_iteration=bst.best_iteration)

  d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
  d_preds['preds'] += [ np.array(val) for val in y_dass21_test_preds ]

print('LightGBM')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:172: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# LightGBM
# ROC AUC:  0.7041
# PR AUC:  0.9087

# %% [markdown]
# ### SVM

# %%
# SVM
d_preds = {'labels': [], 'preds': []}

loo = leave_one_person_out(patient_ids)

for patient_id in loo:
  # Leave one out
  train_indices = np.array(loo[patient_id][0])
  test_indices = np.array(loo[patient_id][1])

  X_rawdata_train = X_rawdata[train_indices]
  X_rawdata_test = X_rawdata[test_indices]
  y_dass21_train = y_dass21[train_indices]
  y_dass21_test = y_dass21[test_indices]

  # Data imputation
  X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                    imputation_method='mean')

  # Classification
  clf = make_pipeline(StandardScaler(), SVC(gamma='auto', probability=True))
  clf.fit(X_rawdata_train, y_dass21_train)
  d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
  d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('SVM')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# SVM
# ROC AUC:  0.578
# PR AUC:  0.8591

# %% [markdown]
# ### Random forest

# %%
# Random forest
d_preds = {'labels': [], 'preds': []}

loo = leave_one_person_out(patient_ids)

for patient_id in loo:
  # Leave one out
  train_indices = np.array(loo[patient_id][0])
  test_indices = np.array(loo[patient_id][1])

  X_rawdata_train = X_rawdata[train_indices]
  X_rawdata_test = X_rawdata[test_indices]
  y_dass21_train = y_dass21[train_indices]
  y_dass21_test = y_dass21[test_indices]

  # Data imputation
  X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                    imputation_method='mean')

  # Classification
  clf = RandomForestClassifier(max_depth=2, random_state=0)
  clf.fit(X_rawdata_train, y_dass21_train)
  d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
  d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('Random forest')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Random forest
# ROC AUC:  0.6232
# PR AUC:  0.8714

# %% [markdown]
# ### MLP

# %%
# MLP

# Define hyperparameters
input_size = X_rawdata.shape[1]
hidden_size = 64
num_epochs = 20
batch_size = 32
dropout_prob = 0.05
learning_rate = 0.001

d_preds = {'labels': [], 'preds': []}

loo = leave_one_person_out(patient_ids)

for patient_id in loo:
  # Leave one out
  train_indices = np.array(loo[patient_id][0])
  test_indices = np.array(loo[patient_id][1])

  X_rawdata_train = X_rawdata[train_indices]
  X_rawdata_test = X_rawdata[test_indices]
  y_dass21_train = y_dass21[train_indices]
  y_dass21_test = y_dass21[test_indices]

  # Data imputation
  X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                    imputation_method='mean')

  # Dummy
  flag = None
  if len(set(y_dass21_test)) == 1:
    for i in range(len(y_dass21)):
      if y_dass21[i] == 1 - y_dass21_test[0]:
        X_rawdata_test = np.concatenate((np.reshape(X_rawdata[i], (1,-1)), X_rawdata_test), axis=0)
        y_dass21_test = np.concatenate((np.array([y_dass21[i]]), y_dass21_test), axis=0)
        flag = True
        break

  # Classification
  MLP_training(X_rawdata_train, X_rawdata_test, y_dass21_train, y_dass21_test)
  y_test_predicted = MLP_inference(X_rawdata_test)

  if flag == True:
    y_dass21_test, y_test_predicted = y_dass21_test[1:], y_test_predicted[1:]

  d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
  d_preds['preds'] += [ np.array(val) for val in y_test_predicted ]

print('MLP')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Epoch [1/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [2/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [3/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [4/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [5/20], Train Accuracy: 0.8028, Test Accuracy: 0.1111
# Epoch [6/20], Train Accuracy: 0.8168, Test Accuracy: 0.1111
# Epoch [7/20], Train Accuracy: 0.8299, Test Accuracy: 0.1111
# Epoch [8/20], Train Accuracy: 0.8458, Test Accuracy: 0.0000
# Epoch [9/20], Train Accuracy: 0.8505, Test Accuracy: 0.0000
# Epoch [10/20], Train Accuracy: 0.8551, Test Accuracy: 0.1111
# Epoch [11/20], Train Accuracy: 0.8598, Test Accuracy: 0.1111
# Epoch [12/20], Train Accuracy: 0.8645, Test Accuracy: 0.1111
# Epoch [13/20], Train Accuracy: 0.8720, Test Accuracy: 0.1111
# Epoch [14/20], Train Accuracy: 0.8748, Test Accuracy: 0.1111
# Epoch [15/20], Train Accuracy: 0.8869, Test Accuracy: 0.1111
# Epoch [16/20], Train Accuracy: 0.8897, Test Accuracy: 0.1111
# Epoch [17/20], Train Accuracy: 0.8944, Test Accuracy: 0.1111
# Epoch [18/20], Train Accuracy: 0.9000, Test Accuracy: 0.1111
# Epoch [19/20], Train Accuracy: 0.9065, Test Accuracy: 0.1111
# Epoch [20/20], Train Accuracy: 0.9084, Test Accuracy: 0.1111
# Epoch [1/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [2/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [3/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [4/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [5/20], Train Accuracy: 0.7998, Test Accuracy: 1.0000
# Epoch [6/20], Train Accuracy: 0.7970, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8026, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8222, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8315, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8454, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8510, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8585, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8603, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8641, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8715, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8734, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8836, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8966, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8976, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8957, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7992, Test Accuracy: 0.0769
# Epoch [2/20], Train Accuracy: 0.7992, Test Accuracy: 0.0769
# Epoch [3/20], Train Accuracy: 0.7992, Test Accuracy: 0.0769
# Epoch [4/20], Train Accuracy: 0.7992, Test Accuracy: 0.0769
# Epoch [5/20], Train Accuracy: 0.8077, Test Accuracy: 0.0769
# Epoch [6/20], Train Accuracy: 0.8096, Test Accuracy: 0.0769
# Epoch [7/20], Train Accuracy: 0.8227, Test Accuracy: 0.0769
# Epoch [8/20], Train Accuracy: 0.8349, Test Accuracy: 0.0769
# Epoch [9/20], Train Accuracy: 0.8443, Test Accuracy: 0.0769
# Epoch [10/20], Train Accuracy: 0.8537, Test Accuracy: 0.0769
# Epoch [11/20], Train Accuracy: 0.8358, Test Accuracy: 0.0769
# Epoch [12/20], Train Accuracy: 0.8433, Test Accuracy: 0.0769
# Epoch [13/20], Train Accuracy: 0.8565, Test Accuracy: 0.0769
# Epoch [14/20], Train Accuracy: 0.8471, Test Accuracy: 0.0769
# Epoch [15/20], Train Accuracy: 0.8865, Test Accuracy: 0.0769
# Epoch [16/20], Train Accuracy: 0.8902, Test Accuracy: 0.0769
# Epoch [17/20], Train Accuracy: 0.8846, Test Accuracy: 0.1538
# Epoch [18/20], Train Accuracy: 0.8949, Test Accuracy: 0.4615
# Epoch [19/20], Train Accuracy: 0.8856, Test Accuracy: 0.0769
# Epoch [20/20], Train Accuracy: 0.9156, Test Accuracy: 0.5385
# Epoch [1/20], Train Accuracy: 0.7872, Test Accuracy: 0.9412
# Epoch [2/20], Train Accuracy: 0.7872, Test Accuracy: 0.9412
# Epoch [3/20], Train Accuracy: 0.7872, Test Accuracy: 0.9412
# Epoch [4/20], Train Accuracy: 0.7957, Test Accuracy: 1.0000
# Epoch [5/20], Train Accuracy: 0.7910, Test Accuracy: 0.9412
# Epoch [6/20], Train Accuracy: 0.8164, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8286, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8145, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8258, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8437, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8597, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8682, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8691, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8719, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8701, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8785, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8870, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8804, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9077, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9011, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7918, Test Accuracy: 0.3333
# Epoch [2/20], Train Accuracy: 0.7918, Test Accuracy: 0.3333
# Epoch [3/20], Train Accuracy: 0.7918, Test Accuracy: 0.3333
# Epoch [4/20], Train Accuracy: 0.7918, Test Accuracy: 0.3333
# Epoch [5/20], Train Accuracy: 0.7918, Test Accuracy: 0.3333
# Epoch [6/20], Train Accuracy: 0.7946, Test Accuracy: 0.3333
# Epoch [7/20], Train Accuracy: 0.8206, Test Accuracy: 0.3333
# Epoch [8/20], Train Accuracy: 0.8206, Test Accuracy: 0.3333
# Epoch [9/20], Train Accuracy: 0.8206, Test Accuracy: 0.6667
# Epoch [10/20], Train Accuracy: 0.8225, Test Accuracy: 0.6667
# Epoch [11/20], Train Accuracy: 0.8188, Test Accuracy: 0.6667
# Epoch [12/20], Train Accuracy: 0.8346, Test Accuracy: 0.6667
# Epoch [13/20], Train Accuracy: 0.8485, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8439, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8717, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8783, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8885, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8857, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8950, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9006, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [2/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [3/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [4/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [5/20], Train Accuracy: 0.7952, Test Accuracy: 1.0000
# Epoch [6/20], Train Accuracy: 0.8026, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8222, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8324, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8426, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8492, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8557, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8557, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8603, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8575, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8641, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8734, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8734, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8762, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8892, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8864, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7892, Test Accuracy: 0.8571
# Epoch [2/20], Train Accuracy: 0.7892, Test Accuracy: 0.8571
# Epoch [3/20], Train Accuracy: 0.7892, Test Accuracy: 0.8571
# Epoch [4/20], Train Accuracy: 0.7892, Test Accuracy: 0.8571
# Epoch [5/20], Train Accuracy: 0.7892, Test Accuracy: 0.8571
# Epoch [6/20], Train Accuracy: 0.8060, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8153, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8209, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8237, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8200, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8498, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8657, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8713, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8750, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8750, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8843, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8871, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8806, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8890, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9142, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.8053, Test Accuracy: 0.0476
# Epoch [2/20], Train Accuracy: 0.8053, Test Accuracy: 0.0476
# Epoch [3/20], Train Accuracy: 0.8053, Test Accuracy: 0.0476
# Epoch [4/20], Train Accuracy: 0.8053, Test Accuracy: 0.0476
# Epoch [5/20], Train Accuracy: 0.8053, Test Accuracy: 0.0476
# Epoch [6/20], Train Accuracy: 0.8081, Test Accuracy: 0.0476
# Epoch [7/20], Train Accuracy: 0.8129, Test Accuracy: 0.0476
# Epoch [8/20], Train Accuracy: 0.8214, Test Accuracy: 0.0476
# Epoch [9/20], Train Accuracy: 0.8270, Test Accuracy: 0.0476
# Epoch [10/20], Train Accuracy: 0.8516, Test Accuracy: 0.0476
# Epoch [11/20], Train Accuracy: 0.8516, Test Accuracy: 0.0476
# Epoch [12/20], Train Accuracy: 0.8497, Test Accuracy: 0.0476
# Epoch [13/20], Train Accuracy: 0.8573, Test Accuracy: 0.0476
# Epoch [14/20], Train Accuracy: 0.8941, Test Accuracy: 0.0476
# Epoch [15/20], Train Accuracy: 0.8743, Test Accuracy: 0.0476
# Epoch [16/20], Train Accuracy: 0.9064, Test Accuracy: 0.0476
# Epoch [17/20], Train Accuracy: 0.9074, Test Accuracy: 0.0476
# Epoch [18/20], Train Accuracy: 0.8998, Test Accuracy: 0.0476
# Epoch [19/20], Train Accuracy: 0.9093, Test Accuracy: 0.0476
# Epoch [20/20], Train Accuracy: 0.9159, Test Accuracy: 0.0476
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.7937, Test Accuracy: 0.6667
# Epoch [7/20], Train Accuracy: 0.7974, Test Accuracy: 0.6667
# Epoch [8/20], Train Accuracy: 0.8216, Test Accuracy: 0.6667
# Epoch [9/20], Train Accuracy: 0.8346, Test Accuracy: 0.6667
# Epoch [10/20], Train Accuracy: 0.8364, Test Accuracy: 0.6667
# Epoch [11/20], Train Accuracy: 0.8420, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8513, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8615, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8792, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8866, Test Accuracy: 0.6667
# Epoch [16/20], Train Accuracy: 0.8950, Test Accuracy: 0.3333
# Epoch [17/20], Train Accuracy: 0.8941, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8922, Test Accuracy: 0.3333
# Epoch [19/20], Train Accuracy: 0.8968, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9080, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7870, Test Accuracy: 0.9444
# Epoch [2/20], Train Accuracy: 0.7870, Test Accuracy: 0.9444
# Epoch [3/20], Train Accuracy: 0.7870, Test Accuracy: 0.9444
# Epoch [4/20], Train Accuracy: 0.7870, Test Accuracy: 0.9444
# Epoch [5/20], Train Accuracy: 0.7870, Test Accuracy: 0.9444
# Epoch [6/20], Train Accuracy: 0.7870, Test Accuracy: 0.9444
# Epoch [7/20], Train Accuracy: 0.7917, Test Accuracy: 0.9444
# Epoch [8/20], Train Accuracy: 0.8143, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8275, Test Accuracy: 0.9444
# Epoch [10/20], Train Accuracy: 0.8285, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8407, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8520, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8605, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8662, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8812, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8812, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8944, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8907, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9010, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9161, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8004, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.7948, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8180, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8236, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8384, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8505, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8672, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8784, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8774, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8626, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8812, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8839, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8960, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9099, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9053, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7929, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7994, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8124, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8199, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8264, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8394, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8422, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8459, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8663, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8598, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8839, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8867, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8830, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8858, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8923, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9109, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7939, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.7920, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.7985, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.7967, Test Accuracy: 0.5000
# Epoch [10/20], Train Accuracy: 0.7994, Test Accuracy: 0.5000
# Epoch [11/20], Train Accuracy: 0.8115, Test Accuracy: 0.5000
# Epoch [12/20], Train Accuracy: 0.8171, Test Accuracy: 0.5000
# Epoch [13/20], Train Accuracy: 0.8366, Test Accuracy: 0.5000
# Epoch [14/20], Train Accuracy: 0.8542, Test Accuracy: 0.5000
# Epoch [15/20], Train Accuracy: 0.8617, Test Accuracy: 0.5000
# Epoch [16/20], Train Accuracy: 0.8709, Test Accuracy: 0.5000
# Epoch [17/20], Train Accuracy: 0.8728, Test Accuracy: 0.5000
# Epoch [18/20], Train Accuracy: 0.8663, Test Accuracy: 0.5000
# Epoch [19/20], Train Accuracy: 0.8821, Test Accuracy: 0.5000
# Epoch [20/20], Train Accuracy: 0.8923, Test Accuracy: 0.5000
# Epoch [1/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7957, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7929, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8171, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8171, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8319, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8496, Test Accuracy: 0.5000
# Epoch [10/20], Train Accuracy: 0.8700, Test Accuracy: 0.5000
# Epoch [11/20], Train Accuracy: 0.8691, Test Accuracy: 0.5000
# Epoch [12/20], Train Accuracy: 0.8812, Test Accuracy: 0.5000
# Epoch [13/20], Train Accuracy: 0.8812, Test Accuracy: 0.5000
# Epoch [14/20], Train Accuracy: 0.8858, Test Accuracy: 0.5000
# Epoch [15/20], Train Accuracy: 0.8904, Test Accuracy: 0.5000
# Epoch [16/20], Train Accuracy: 0.9025, Test Accuracy: 0.5000
# Epoch [17/20], Train Accuracy: 0.9006, Test Accuracy: 0.5000
# Epoch [18/20], Train Accuracy: 0.9099, Test Accuracy: 0.5000
# Epoch [19/20], Train Accuracy: 0.9220, Test Accuracy: 0.5000
# Epoch [20/20], Train Accuracy: 0.9313, Test Accuracy: 0.5000
# Epoch [1/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7985, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8041, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8347, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8319, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8366, Test Accuracy: 0.5000
# Epoch [10/20], Train Accuracy: 0.8589, Test Accuracy: 0.5000
# Epoch [11/20], Train Accuracy: 0.8542, Test Accuracy: 0.5000
# Epoch [12/20], Train Accuracy: 0.8598, Test Accuracy: 0.5000
# Epoch [13/20], Train Accuracy: 0.8793, Test Accuracy: 0.5000
# Epoch [14/20], Train Accuracy: 0.8747, Test Accuracy: 0.5000
# Epoch [15/20], Train Accuracy: 0.8747, Test Accuracy: 0.5000
# Epoch [16/20], Train Accuracy: 0.8849, Test Accuracy: 0.5000
# Epoch [17/20], Train Accuracy: 0.8969, Test Accuracy: 0.5000
# Epoch [18/20], Train Accuracy: 0.8942, Test Accuracy: 0.5000
# Epoch [19/20], Train Accuracy: 0.9006, Test Accuracy: 0.5000
# Epoch [20/20], Train Accuracy: 0.9071, Test Accuracy: 0.5000
# Epoch [1/20], Train Accuracy: 0.7933, Test Accuracy: 0.2000
# Epoch [2/20], Train Accuracy: 0.7933, Test Accuracy: 0.2000
# Epoch [3/20], Train Accuracy: 0.7933, Test Accuracy: 0.2000
# Epoch [4/20], Train Accuracy: 0.7933, Test Accuracy: 0.2000
# Epoch [5/20], Train Accuracy: 0.7933, Test Accuracy: 0.2000
# Epoch [6/20], Train Accuracy: 0.7933, Test Accuracy: 0.2000
# Epoch [7/20], Train Accuracy: 0.7933, Test Accuracy: 0.2000
# Epoch [8/20], Train Accuracy: 0.7952, Test Accuracy: 0.2000
# Epoch [9/20], Train Accuracy: 0.8045, Test Accuracy: 0.2000
# Epoch [10/20], Train Accuracy: 0.8045, Test Accuracy: 0.6000
# Epoch [11/20], Train Accuracy: 0.8101, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8287, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8222, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8343, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8529, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8473, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8566, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8575, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8547, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8771, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7918, Test Accuracy: 0.3333
# Epoch [2/20], Train Accuracy: 0.7918, Test Accuracy: 0.3333
# Epoch [3/20], Train Accuracy: 0.7918, Test Accuracy: 0.3333
# Epoch [4/20], Train Accuracy: 0.7918, Test Accuracy: 0.3333
# Epoch [5/20], Train Accuracy: 0.7955, Test Accuracy: 0.3333
# Epoch [6/20], Train Accuracy: 0.8020, Test Accuracy: 0.3333
# Epoch [7/20], Train Accuracy: 0.8216, Test Accuracy: 0.3333
# Epoch [8/20], Train Accuracy: 0.8271, Test Accuracy: 0.3333
# Epoch [9/20], Train Accuracy: 0.8253, Test Accuracy: 0.3333
# Epoch [10/20], Train Accuracy: 0.8160, Test Accuracy: 0.3333
# Epoch [11/20], Train Accuracy: 0.8346, Test Accuracy: 0.3333
# Epoch [12/20], Train Accuracy: 0.8439, Test Accuracy: 0.3333
# Epoch [13/20], Train Accuracy: 0.8643, Test Accuracy: 0.3333
# Epoch [14/20], Train Accuracy: 0.8634, Test Accuracy: 0.3333
# Epoch [15/20], Train Accuracy: 0.8810, Test Accuracy: 0.3333
# Epoch [16/20], Train Accuracy: 0.8727, Test Accuracy: 0.3333
# Epoch [17/20], Train Accuracy: 0.8745, Test Accuracy: 0.3333
# Epoch [18/20], Train Accuracy: 0.8736, Test Accuracy: 0.3333
# Epoch [19/20], Train Accuracy: 0.8903, Test Accuracy: 0.3333
# Epoch [20/20], Train Accuracy: 0.8894, Test Accuracy: 0.3333
# Epoch [1/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [2/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [3/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [4/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [5/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [6/20], Train Accuracy: 0.8037, Test Accuracy: 0.1111
# Epoch [7/20], Train Accuracy: 0.8121, Test Accuracy: 0.1111
# Epoch [8/20], Train Accuracy: 0.8252, Test Accuracy: 0.1111
# Epoch [9/20], Train Accuracy: 0.8336, Test Accuracy: 0.1111
# Epoch [10/20], Train Accuracy: 0.8430, Test Accuracy: 0.1111
# Epoch [11/20], Train Accuracy: 0.8393, Test Accuracy: 0.1111
# Epoch [12/20], Train Accuracy: 0.8570, Test Accuracy: 0.1111
# Epoch [13/20], Train Accuracy: 0.8336, Test Accuracy: 0.1111
# Epoch [14/20], Train Accuracy: 0.8533, Test Accuracy: 0.1111
# Epoch [15/20], Train Accuracy: 0.8785, Test Accuracy: 0.1111
# Epoch [16/20], Train Accuracy: 0.8869, Test Accuracy: 0.1111
# Epoch [17/20], Train Accuracy: 0.8804, Test Accuracy: 0.1111
# Epoch [18/20], Train Accuracy: 0.8860, Test Accuracy: 0.1111
# Epoch [19/20], Train Accuracy: 0.8850, Test Accuracy: 0.1111
# Epoch [20/20], Train Accuracy: 0.8916, Test Accuracy: 0.1111
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7957, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8050, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8199, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8301, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8254, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8487, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8524, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8598, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8561, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8700, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8700, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8821, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8886, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8923, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8867, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8849, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [2/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [3/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [4/20], Train Accuracy: 0.7903, Test Accuracy: 0.9091
# Epoch [5/20], Train Accuracy: 0.7978, Test Accuracy: 0.9091
# Epoch [6/20], Train Accuracy: 0.8043, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8137, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8287, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8521, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8558, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8633, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8801, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8745, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8839, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8904, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9036, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9073, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9054, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9195, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9185, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.7974, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.8095, Test Accuracy: 0.6667
# Epoch [7/20], Train Accuracy: 0.8104, Test Accuracy: 0.6667
# Epoch [8/20], Train Accuracy: 0.8104, Test Accuracy: 0.6667
# Epoch [9/20], Train Accuracy: 0.8123, Test Accuracy: 0.6667
# Epoch [10/20], Train Accuracy: 0.8048, Test Accuracy: 0.6667
# Epoch [11/20], Train Accuracy: 0.8253, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8243, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8318, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8309, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8652, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8625, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8745, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8810, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8848, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8959, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8097, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8115, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8329, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8533, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8552, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8598, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8672, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8821, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8849, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8979, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8979, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9016, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9071, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9090, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9285, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7888, Test Accuracy: 0.8889
# Epoch [2/20], Train Accuracy: 0.7888, Test Accuracy: 0.8889
# Epoch [3/20], Train Accuracy: 0.7888, Test Accuracy: 0.8889
# Epoch [4/20], Train Accuracy: 0.7888, Test Accuracy: 0.8889
# Epoch [5/20], Train Accuracy: 0.7935, Test Accuracy: 1.0000
# Epoch [6/20], Train Accuracy: 0.8065, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8150, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8224, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8187, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8411, Test Accuracy: 0.8889
# Epoch [11/20], Train Accuracy: 0.8421, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8495, Test Accuracy: 0.3333
# Epoch [13/20], Train Accuracy: 0.8720, Test Accuracy: 0.3333
# Epoch [14/20], Train Accuracy: 0.8710, Test Accuracy: 0.1111
# Epoch [15/20], Train Accuracy: 0.8776, Test Accuracy: 0.8889
# Epoch [16/20], Train Accuracy: 0.8991, Test Accuracy: 0.1111
# Epoch [17/20], Train Accuracy: 0.9065, Test Accuracy: 0.1111
# Epoch [18/20], Train Accuracy: 0.9047, Test Accuracy: 0.4444
# Epoch [19/20], Train Accuracy: 0.9178, Test Accuracy: 0.1111
# Epoch [20/20], Train Accuracy: 0.9103, Test Accuracy: 0.1111
# Epoch [1/20], Train Accuracy: 0.7876, Test Accuracy: 0.9333
# Epoch [2/20], Train Accuracy: 0.7876, Test Accuracy: 0.9333
# Epoch [3/20], Train Accuracy: 0.7876, Test Accuracy: 0.9333
# Epoch [4/20], Train Accuracy: 0.7876, Test Accuracy: 0.9333
# Epoch [5/20], Train Accuracy: 0.7876, Test Accuracy: 0.9333
# Epoch [6/20], Train Accuracy: 0.7923, Test Accuracy: 0.9333
# Epoch [7/20], Train Accuracy: 0.8111, Test Accuracy: 0.8667
# Epoch [8/20], Train Accuracy: 0.8102, Test Accuracy: 0.3333
# Epoch [9/20], Train Accuracy: 0.8177, Test Accuracy: 0.8667
# Epoch [10/20], Train Accuracy: 0.8299, Test Accuracy: 0.2000
# Epoch [11/20], Train Accuracy: 0.8214, Test Accuracy: 0.6000
# Epoch [12/20], Train Accuracy: 0.8365, Test Accuracy: 0.3333
# Epoch [13/20], Train Accuracy: 0.8393, Test Accuracy: 0.6000
# Epoch [14/20], Train Accuracy: 0.8600, Test Accuracy: 0.2000
# Epoch [15/20], Train Accuracy: 0.8487, Test Accuracy: 0.6000
# Epoch [16/20], Train Accuracy: 0.8628, Test Accuracy: 0.3333
# Epoch [17/20], Train Accuracy: 0.8628, Test Accuracy: 0.0667
# Epoch [18/20], Train Accuracy: 0.8741, Test Accuracy: 0.9333
# Epoch [19/20], Train Accuracy: 0.8806, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8872, Test Accuracy: 0.4667
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7920, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8124, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8199, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8217, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8319, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8533, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8542, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8672, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8719, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8793, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8802, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8830, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8932, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8979, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8886, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8143, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8236, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8264, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8338, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8524, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8524, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8579, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8654, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8765, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8691, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8747, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8886, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8960, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9025, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8914, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.7890, Test Accuracy: 0.6667
# Epoch [7/20], Train Accuracy: 0.8058, Test Accuracy: 0.6667
# Epoch [8/20], Train Accuracy: 0.8086, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8132, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8271, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8299, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8355, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8429, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8504, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8597, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8690, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8783, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8643, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8875, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8978, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7872, Test Accuracy: 0.9412
# Epoch [2/20], Train Accuracy: 0.7872, Test Accuracy: 0.9412
# Epoch [3/20], Train Accuracy: 0.7872, Test Accuracy: 0.9412
# Epoch [4/20], Train Accuracy: 0.7872, Test Accuracy: 0.9412
# Epoch [5/20], Train Accuracy: 0.7863, Test Accuracy: 0.9412
# Epoch [6/20], Train Accuracy: 0.7872, Test Accuracy: 0.9412
# Epoch [7/20], Train Accuracy: 0.7994, Test Accuracy: 0.9412
# Epoch [8/20], Train Accuracy: 0.8032, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8051, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8173, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8126, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8352, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8296, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8559, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8653, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8578, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8729, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8738, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8814, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8898, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [2/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [3/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [4/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [5/20], Train Accuracy: 0.7933, Test Accuracy: 0.8000
# Epoch [6/20], Train Accuracy: 0.8054, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8073, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8212, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8408, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8277, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8520, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8575, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8687, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8696, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8780, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8594, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8845, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8883, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8966, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8966, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.7937, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.7946, Test Accuracy: 0.6667
# Epoch [7/20], Train Accuracy: 0.8104, Test Accuracy: 0.6667
# Epoch [8/20], Train Accuracy: 0.8151, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8160, Test Accuracy: 0.6667
# Epoch [10/20], Train Accuracy: 0.8262, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8225, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8541, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8625, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8634, Test Accuracy: 0.6667
# Epoch [15/20], Train Accuracy: 0.8755, Test Accuracy: 0.6667
# Epoch [16/20], Train Accuracy: 0.8680, Test Accuracy: 0.6667
# Epoch [17/20], Train Accuracy: 0.8755, Test Accuracy: 0.6667
# Epoch [18/20], Train Accuracy: 0.8773, Test Accuracy: 0.6667
# Epoch [19/20], Train Accuracy: 0.8885, Test Accuracy: 0.6667
# Epoch [20/20], Train Accuracy: 0.8987, Test Accuracy: 0.6667
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.7937, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.7890, Test Accuracy: 0.6667
# Epoch [7/20], Train Accuracy: 0.8020, Test Accuracy: 0.6667
# Epoch [8/20], Train Accuracy: 0.8113, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8141, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8262, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8299, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8494, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8522, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8532, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8662, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8671, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8736, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8690, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8783, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8792, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.7918, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.7955, Test Accuracy: 0.6667
# Epoch [7/20], Train Accuracy: 0.8132, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8439, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8411, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8513, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8309, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8522, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8587, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8690, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8671, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8541, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8717, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8857, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8885, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8950, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [7/20], Train Accuracy: 0.7909, Test Accuracy: 0.6667
# Epoch [8/20], Train Accuracy: 0.8048, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8076, Test Accuracy: 0.6667
# Epoch [10/20], Train Accuracy: 0.8271, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8346, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8290, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8494, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8606, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8559, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8755, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8699, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8745, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8820, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8931, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [2/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [3/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [4/20], Train Accuracy: 0.7905, Test Accuracy: 0.8000
# Epoch [5/20], Train Accuracy: 0.8007, Test Accuracy: 0.8000
# Epoch [6/20], Train Accuracy: 0.8128, Test Accuracy: 0.8000
# Epoch [7/20], Train Accuracy: 0.8250, Test Accuracy: 0.8000
# Epoch [8/20], Train Accuracy: 0.8184, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8259, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8436, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8557, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8659, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8547, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8734, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8808, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8892, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8948, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8818, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9022, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9125, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [2/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [3/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [4/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [5/20], Train Accuracy: 0.7942, Test Accuracy: 0.8000
# Epoch [6/20], Train Accuracy: 0.8035, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8054, Test Accuracy: 0.8000
# Epoch [8/20], Train Accuracy: 0.8250, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8231, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8464, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8417, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8631, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8613, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8808, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8818, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8734, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8883, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9041, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9143, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9050, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [2/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [3/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [4/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [5/20], Train Accuracy: 0.7972, Test Accuracy: 0.1111
# Epoch [6/20], Train Accuracy: 0.8028, Test Accuracy: 0.1111
# Epoch [7/20], Train Accuracy: 0.8131, Test Accuracy: 0.1111
# Epoch [8/20], Train Accuracy: 0.8103, Test Accuracy: 0.1111
# Epoch [9/20], Train Accuracy: 0.8140, Test Accuracy: 0.1111
# Epoch [10/20], Train Accuracy: 0.8374, Test Accuracy: 0.1111
# Epoch [11/20], Train Accuracy: 0.8486, Test Accuracy: 0.1111
# Epoch [12/20], Train Accuracy: 0.8654, Test Accuracy: 0.1111
# Epoch [13/20], Train Accuracy: 0.8579, Test Accuracy: 0.1111
# Epoch [14/20], Train Accuracy: 0.8701, Test Accuracy: 0.4444
# Epoch [15/20], Train Accuracy: 0.8701, Test Accuracy: 0.1111
# Epoch [16/20], Train Accuracy: 0.8860, Test Accuracy: 0.1111
# Epoch [17/20], Train Accuracy: 0.8710, Test Accuracy: 0.2222
# Epoch [18/20], Train Accuracy: 0.8869, Test Accuracy: 0.1111
# Epoch [19/20], Train Accuracy: 0.8991, Test Accuracy: 0.1111
# Epoch [20/20], Train Accuracy: 0.9047, Test Accuracy: 0.1111
# Epoch [1/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [2/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [3/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [4/20], Train Accuracy: 0.7896, Test Accuracy: 0.8000
# Epoch [5/20], Train Accuracy: 0.7905, Test Accuracy: 0.8000
# Epoch [6/20], Train Accuracy: 0.7952, Test Accuracy: 0.8000
# Epoch [7/20], Train Accuracy: 0.8063, Test Accuracy: 0.8000
# Epoch [8/20], Train Accuracy: 0.8156, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8287, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8389, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8445, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8650, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8622, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8622, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8827, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8808, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8836, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9022, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8929, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9041, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [5/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [6/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [7/20], Train Accuracy: 0.7983, Test Accuracy: 0.6667
# Epoch [8/20], Train Accuracy: 0.8048, Test Accuracy: 0.3333
# Epoch [9/20], Train Accuracy: 0.8104, Test Accuracy: 0.3333
# Epoch [10/20], Train Accuracy: 0.8104, Test Accuracy: 0.3333
# Epoch [11/20], Train Accuracy: 0.8243, Test Accuracy: 0.3333
# Epoch [12/20], Train Accuracy: 0.8420, Test Accuracy: 0.3333
# Epoch [13/20], Train Accuracy: 0.8541, Test Accuracy: 0.3333
# Epoch [14/20], Train Accuracy: 0.8615, Test Accuracy: 0.3333
# Epoch [15/20], Train Accuracy: 0.8597, Test Accuracy: 0.3333
# Epoch [16/20], Train Accuracy: 0.8671, Test Accuracy: 0.3333
# Epoch [17/20], Train Accuracy: 0.8764, Test Accuracy: 0.3333
# Epoch [18/20], Train Accuracy: 0.8717, Test Accuracy: 0.3333
# Epoch [19/20], Train Accuracy: 0.8764, Test Accuracy: 0.3333
# Epoch [20/20], Train Accuracy: 0.8857, Test Accuracy: 0.3333
# Epoch [1/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [2/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [3/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [4/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [5/20], Train Accuracy: 0.7963, Test Accuracy: 0.1111
# Epoch [6/20], Train Accuracy: 0.7981, Test Accuracy: 0.1111
# Epoch [7/20], Train Accuracy: 0.8178, Test Accuracy: 0.1111
# Epoch [8/20], Train Accuracy: 0.8178, Test Accuracy: 0.1111
# Epoch [9/20], Train Accuracy: 0.8542, Test Accuracy: 0.1111
# Epoch [10/20], Train Accuracy: 0.8673, Test Accuracy: 0.1111
# Epoch [11/20], Train Accuracy: 0.8813, Test Accuracy: 0.1111
# Epoch [12/20], Train Accuracy: 0.8869, Test Accuracy: 0.1111
# Epoch [13/20], Train Accuracy: 0.8804, Test Accuracy: 0.1111
# Epoch [14/20], Train Accuracy: 0.8888, Test Accuracy: 0.1111
# Epoch [15/20], Train Accuracy: 0.8860, Test Accuracy: 0.1111
# Epoch [16/20], Train Accuracy: 0.8897, Test Accuracy: 0.1111
# Epoch [17/20], Train Accuracy: 0.8935, Test Accuracy: 0.1111
# Epoch [18/20], Train Accuracy: 0.8981, Test Accuracy: 0.1111
# Epoch [19/20], Train Accuracy: 0.8981, Test Accuracy: 0.1111
# Epoch [20/20], Train Accuracy: 0.9103, Test Accuracy: 0.1111
# Epoch [1/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [2/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [3/20], Train Accuracy: 0.7900, Test Accuracy: 0.6667
# Epoch [4/20], Train Accuracy: 0.7946, Test Accuracy: 1.0000
# Epoch [5/20], Train Accuracy: 0.7974, Test Accuracy: 1.0000
# Epoch [6/20], Train Accuracy: 0.7974, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8141, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8271, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8457, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8392, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8374, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8401, Test Accuracy: 1.0000
# ...
# Epoch [18/20], Train Accuracy: 0.8914, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8997, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9090, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7929, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8087, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8115, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8208, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8227, Test Accuracy: 0.5000
# Epoch [10/20], Train Accuracy: 0.8292, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8440, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8403, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8403, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8579, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8830, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8756, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8877, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8821, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8793, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8849, Test Accuracy: 0.5000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.8097, Test Accuracy: 1.0000
# Epoch [6/20], Train Accuracy: 0.8143, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8208, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8264, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8292, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8301, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8459, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8542, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8737, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8691, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8821, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8886, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8942, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8988, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9062, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9192, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7939, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7957, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8199, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8171, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8227, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8357, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8561, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8440, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8709, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8682, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8774, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8812, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8904, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8774, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8951, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9034, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7880, Test Accuracy: 0.9231
# Epoch [2/20], Train Accuracy: 0.7880, Test Accuracy: 0.9231
# Epoch [3/20], Train Accuracy: 0.7880, Test Accuracy: 0.9231
# Epoch [4/20], Train Accuracy: 0.7889, Test Accuracy: 0.9231
# Epoch [5/20], Train Accuracy: 0.8002, Test Accuracy: 0.9231
# Epoch [6/20], Train Accuracy: 0.8152, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.8208, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8311, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8349, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8499, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8358, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8546, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8696, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8687, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8809, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8668, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8790, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8734, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8959, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8762, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7976, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8041, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8217, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8264, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8301, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8403, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8607, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8561, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8654, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8719, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8765, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8774, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8784, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8877, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8877, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [2/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [3/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [4/20], Train Accuracy: 0.7884, Test Accuracy: 0.9091
# Epoch [5/20], Train Accuracy: 0.7921, Test Accuracy: 0.9091
# Epoch [6/20], Train Accuracy: 0.8015, Test Accuracy: 0.8182
# Epoch [7/20], Train Accuracy: 0.8174, Test Accuracy: 0.3636
# Epoch [8/20], Train Accuracy: 0.8399, Test Accuracy: 0.3636
# Epoch [9/20], Train Accuracy: 0.8249, Test Accuracy: 0.3636
# Epoch [10/20], Train Accuracy: 0.8390, Test Accuracy: 0.3636
# Epoch [11/20], Train Accuracy: 0.8558, Test Accuracy: 0.3636
# Epoch [12/20], Train Accuracy: 0.8558, Test Accuracy: 0.3636
# Epoch [13/20], Train Accuracy: 0.8820, Test Accuracy: 0.1818
# Epoch [14/20], Train Accuracy: 0.8727, Test Accuracy: 0.2727
# Epoch [15/20], Train Accuracy: 0.8792, Test Accuracy: 0.1818
# Epoch [16/20], Train Accuracy: 0.8820, Test Accuracy: 0.2727
# Epoch [17/20], Train Accuracy: 0.8886, Test Accuracy: 0.1818
# Epoch [18/20], Train Accuracy: 0.8933, Test Accuracy: 0.2727
# Epoch [19/20], Train Accuracy: 0.8998, Test Accuracy: 0.1818
# Epoch [20/20], Train Accuracy: 0.8951, Test Accuracy: 0.2727
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7948, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8124, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8217, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8217, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8394, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8273, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8589, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8579, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8607, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8867, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8923, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8988, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.9044, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8951, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9062, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9257, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7929, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7976, Test Accuracy: 1.0000
# Epoch [7/20], Train Accuracy: 0.7976, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8189, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8384, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8366, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8449, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8459, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8607, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8691, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8672, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8774, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8812, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8951, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8969, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9136, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7920, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.8013, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8041, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8217, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8496, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8561, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8496, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8607, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8412, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8774, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8728, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8793, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.9025, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8914, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9034, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9099, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9183, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8022, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8162, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8162, Test Accuracy: 0.5000
# Epoch [10/20], Train Accuracy: 0.8282, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8347, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8301, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8617, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8598, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8682, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8830, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8821, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.9016, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8997, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9044, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7985, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8106, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8152, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8199, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8282, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8570, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8561, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8552, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8737, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8858, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8793, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8839, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8858, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.9016, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.9025, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.7902, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.7920, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.7929, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8162, Test Accuracy: 1.0000
# Epoch [8/20], Train Accuracy: 0.8245, Test Accuracy: 1.0000
# Epoch [9/20], Train Accuracy: 0.8487, Test Accuracy: 1.0000
# Epoch [10/20], Train Accuracy: 0.8366, Test Accuracy: 1.0000
# Epoch [11/20], Train Accuracy: 0.8496, Test Accuracy: 1.0000
# Epoch [12/20], Train Accuracy: 0.8468, Test Accuracy: 1.0000
# Epoch [13/20], Train Accuracy: 0.8589, Test Accuracy: 1.0000
# Epoch [14/20], Train Accuracy: 0.8589, Test Accuracy: 1.0000
# Epoch [15/20], Train Accuracy: 0.8672, Test Accuracy: 1.0000
# Epoch [16/20], Train Accuracy: 0.8700, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8709, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8719, Test Accuracy: 1.0000
# Epoch [19/20], Train Accuracy: 0.8877, Test Accuracy: 1.0000
# Epoch [20/20], Train Accuracy: 0.8997, Test Accuracy: 1.0000
# Epoch [1/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [2/20], Train Accuracy: 0.7911, Test Accuracy: 0.5000
# Epoch [3/20], Train Accuracy: 0.7920, Test Accuracy: 0.5000
# Epoch [4/20], Train Accuracy: 0.8013, Test Accuracy: 0.5000
# Epoch [5/20], Train Accuracy: 0.8078, Test Accuracy: 0.5000
# Epoch [6/20], Train Accuracy: 0.8134, Test Accuracy: 0.5000
# Epoch [7/20], Train Accuracy: 0.8199, Test Accuracy: 0.5000
# Epoch [8/20], Train Accuracy: 0.8097, Test Accuracy: 0.5000
# Epoch [9/20], Train Accuracy: 0.8273, Test Accuracy: 0.5000
# Epoch [10/20], Train Accuracy: 0.8403, Test Accuracy: 0.5000
# Epoch [11/20], Train Accuracy: 0.8514, Test Accuracy: 0.5000
# Epoch [12/20], Train Accuracy: 0.8459, Test Accuracy: 0.5000
# Epoch [13/20], Train Accuracy: 0.8644, Test Accuracy: 0.5000
# Epoch [14/20], Train Accuracy: 0.8579, Test Accuracy: 0.5000
# Epoch [15/20], Train Accuracy: 0.8737, Test Accuracy: 0.5000
# Epoch [16/20], Train Accuracy: 0.8598, Test Accuracy: 1.0000
# Epoch [17/20], Train Accuracy: 0.8793, Test Accuracy: 1.0000
# Epoch [18/20], Train Accuracy: 0.8747, Test Accuracy: 0.5000
# Epoch [19/20], Train Accuracy: 0.8728, Test Accuracy: 0.5000
# Epoch [20/20], Train Accuracy: 0.8886, Test Accuracy: 1.0000
# MLP
# ROC AUC:  0.5454
# PR AUC:  0.8413

# %% [markdown]
# ## K-fold

# %% [markdown]
# ### Gradient Boosting

# %%
# Gradient Boosting
d_preds = {'labels': [], 'preds': []}

for seed in range(10):
  kfold = k_fold(patient_ids, number_of_folds=5)
  for k in kfold:
    # K-fold
    train_indices = np.array(kfold[k][0])
    test_indices = np.array(kfold[k][1])

    X_rawdata_train = X_rawdata[train_indices]
    X_rawdata_test = X_rawdata[test_indices]
    y_dass21_train = y_dass21[train_indices]
    y_dass21_test = y_dass21[test_indices]

    # Data imputation
    X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                      imputation_method='mean')

    # Classification
    clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
                                    max_depth=1, random_state=0).fit(X_rawdata_train, y_dass21_train)
    d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
    d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('Gradient Boosting')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Gradient Boosting
# ROC AUC:  0.6594
# PR AUC:  0.8723

# %% [markdown]
# ### Catboost

# %%
# Catboost
d_preds = {'labels': [], 'preds': []}

for seed in range(10):
  kfold = k_fold(patient_ids, number_of_folds=5)
  for k in kfold:
    # K-fold
    train_indices = np.array(kfold[k][0])
    test_indices = np.array(kfold[k][1])

    X_rawdata_train = X_rawdata[train_indices]
    X_rawdata_test = X_rawdata[test_indices]
    y_dass21_train = y_dass21[train_indices]
    y_dass21_test = y_dass21[test_indices]

    # Data imputation
    X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                      imputation_method='mean')

    # Classification
    clf = CatBoostClassifier(iterations=2, learning_rate=1, depth=2)
    clf.fit(X_rawdata_train, y_dass21_train, verbose=False)
    d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
    d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('Catboost')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Catboost
# ROC AUC:  0.6173
# PR AUC:  0.8512

# %% [markdown]
# ### LightGBM

# %%
# LightGBM
d_preds = {'labels': [], 'preds': []}

for seed in range(10):
  kfold = k_fold(patient_ids, number_of_folds=5)
  for k in kfold:
    # K-fold
    train_indices = np.array(kfold[k][0])
    test_indices = np.array(kfold[k][1])

    X_rawdata_train = X_rawdata[train_indices]
    X_rawdata_test = X_rawdata[test_indices]
    y_dass21_train = y_dass21[train_indices]
    y_dass21_test = y_dass21[test_indices]

    # Data imputation
    X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                      imputation_method='mean')

    # Classification
  train_data = lgb.Dataset(X_rawdata_train, label=y_dass21_train)
  test_data = lgb.Dataset(X_rawdata_test, label=y_dass21_test, reference=train_data)
  params = {
      'objective': 'binary',
      'metric': 'binary_logloss',
      'num_leaves': 31,
      #'learning_rate': 0.05,
      'learning_rate': 0.1,
      'n_estimators': 100,
      'verbose': -1
  }
  bst = lgb.train(params, train_data, valid_sets=[train_data, test_data])
  y_dass21_test_preds = bst.predict(X_rawdata_test, num_iteration=bst.best_iteration)

  d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
  d_preds['preds'] += [ np.array(val) for val in y_dass21_test_preds ]

print('LightGBM')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:172: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# LightGBM
# ROC AUC:  0.7168
# PR AUC:  0.8852

# %% [markdown]
# ### SVM

# %%
# SVM
d_preds = {'labels': [], 'preds': []}

for seed in range(10):
  kfold = k_fold(patient_ids, number_of_folds=5)
  for k in kfold:
    # K-fold
    train_indices = np.array(kfold[k][0])
    test_indices = np.array(kfold[k][1])

    X_rawdata_train = X_rawdata[train_indices]
    X_rawdata_test = X_rawdata[test_indices]
    y_dass21_train = y_dass21[train_indices]
    y_dass21_test = y_dass21[test_indices]

    # Data imputation
    X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                      imputation_method='mean')

    # Classification
    clf = make_pipeline(StandardScaler(), SVC(gamma='auto', probability=True))
    clf.fit(X_rawdata_train, y_dass21_train)
    d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
    d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('SVM')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# SVM
# ROC AUC:  0.5692
# PR AUC:  0.841

# %% [markdown]
# ### Random forest

# %%
# Random forest
d_preds = {'labels': [], 'preds': []}

for seed in range(10):
  kfold = k_fold(patient_ids, number_of_folds=5)
  for k in kfold:
    # K-fold
    train_indices = np.array(kfold[k][0])
    test_indices = np.array(kfold[k][1])

    X_rawdata_train = X_rawdata[train_indices]
    X_rawdata_test = X_rawdata[test_indices]
    y_dass21_train = y_dass21[train_indices]
    y_dass21_test = y_dass21[test_indices]

    # Data imputation
    X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                      imputation_method='mean')

    # Classification
    clf = RandomForestClassifier(max_depth=2, random_state=0)
    clf.fit(X_rawdata_train, y_dass21_train)
    d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
    d_preds['preds'] += [ np.array(val) for val in clf.predict_proba(X_rawdata_test)[:, 1] ]

print('Random forest')
AUC_plot(d_preds['labels'], d_preds['preds'])
# Out:
# Random forest
# ROC AUC:  0.6402
# PR AUC:  0.8754

# %% [markdown]
# ### MLP

# %%
# MLP

# Define hyperparameters
input_size = X_rawdata.shape[1]
hidden_size = 64
num_epochs = 20
batch_size = 32
dropout_prob = 0.05
learning_rate = 0.001

d_preds = {'labels': [], 'preds': []}

for seed in range(10):
  kfold = k_fold(patient_ids, number_of_folds=5)
  for k in kfold:
    # K-fold
    train_indices = np.array(kfold[k][0])
    test_indices = np.array(kfold[k][1])

    X_rawdata_train = X_rawdata[train_indices]
    X_rawdata_test = X_rawdata[test_indices]
    y_dass21_train = y_dass21[train_indices]
    y_dass21_test = y_dass21[test_indices]

    # Data imputation
    X_rawdata_train, X_rawdata_test = data_imputation(X_rawdata_train, X_rawdata_test,
                                                      imputation_method='mean')

    # Dummy
    flag = None
    if len(set(y_dass21_test)) == 1:
      for i in range(len(y_dass21)):
        if y_dass21[i] == 1 - y_dass21_test[0]:
          X_rawdata_test = np.concatenate((np.reshape(X_rawdata[i], (1,-1)), X_rawdata_test), axis=0)
          y_dass21_test = np.concatenate((np.array([y_dass21[i]]), y_dass21_test), axis=0)
          flag = True
          break

    # Classification
    MLP_training(X_rawdata_train, X_rawdata_test, y_dass21_train, y_dass21_test)
    y_test_predicted = MLP_inference(X_rawdata_test)

    if flag == True:
      y_dass21_test, y_test_predicted = y_dass21_test[1:], y_test_predicted[1:]

    d_preds['labels'] += [ np.array(val) for val in y_dass21_test ]
    d_preds['preds'] += [ np.array(val) for val in y_test_predicted ]

print('MLP')
AUC_plot(d_preds['labels'], d_preds['preds'])
